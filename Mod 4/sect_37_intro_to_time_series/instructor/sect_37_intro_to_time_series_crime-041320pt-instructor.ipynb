# %% [markdown]
# # Sect 37: Intro to Time Series

# %% [markdown]
# - online-ds-pt-041320
# - 10/21/20

# %% [markdown]
# ## Learning Objectives:

# %% [markdown]
# - Learn how to load in timeseries data into pandas
# - Learn how to plot timeseries in pandas
# - Learn how to resample at different time frequencies
# - Learn about types of time series trends and how to remove them.
# - Learn about seasonal decomposition
#
# - Prepare a time series dataset to use for modeling next class

# %% [markdown]
# ## Questions?

# %% [markdown]
# ## Announcements

# %% [markdown]
# > For section 38: Time Series Models, you **NEED to do one of the appendix labs in order to fully learn time series modeling**.
# - Appendix > More Time Series > SARIMA Lab

# %% [markdown]
# # Intro to Time Series

# %% [markdown]
# ## References

# %% [markdown]
# - [Pandas Timeseries Documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html)
# - ['Timeseries Offset Aliases'](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases)
# - [Anchored Offsets](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#anchored-offsets)
#
#
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timestamp.html

# %% [markdown]
# ## Working with Time Series

# %%
# !pip install -U fsds 
from fsds.imports import *

import warnings
warnings.filterwarnings('ignore')

## Setting figures to timeseries-friendly
mpl.rcParams['figure.figsize'] = (12,6)

import os,sys

# %%
sns.__version__

# %% [markdown]
# ### Creating a Time Series from a DataFrame

# %%
df = pd.read_csv('../baltimore_crime_2020.csv',low_memory=False,
                usecols=range(12))

df

# %% [markdown]
# ## Preparing Data for Time Series Visualization

# %% [markdown]
# - Index must be a `datetimeindex`

# %%
df.index
# Out:
# RangeIndex(start=0, stop=300336, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300336 entries, 0 to 300335
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   CrimeDate       300336 non-null  object
#  1   CrimeTime       300311 non-null  object
#  2   CrimeCode       300336 non-null  object
#  3   Location        298968 non-null  object
#  4   Description     300336 non-null  object
#  5   Inside/Outside  264873 non-null  object
#  6   Weapon          63400 non-null   object
#  7   Post            297922 non-null  object
#  8   District        300336 non-null  object
#  9   Neighborhood    289774 non-null  object
#  10  Longitude       298658 non-null  float64
#  11  Latitude        298658 non-null  float64
# dtypes: float64(2), object(10)
# memory usage: 27.5+ MB

# %% [markdown]
# > #### Queston: We need to make a datetime index from the CrimeDate and CrimeTime. How might we do that?

# %%
# Make datetime variable from two columns
datetimeindex = pd.to_datetime(df['CrimeDate']+ ' - ' +df['CrimeTime'])
datetimeindex
# Out:
# 0        2020-04-25 17:30:00
# 1        2020-04-25 02:40:00
# 2        2020-04-25 09:30:00
# 3        2020-04-25 02:30:00
# 4        2020-04-25 15:30:00
#                  ...
# 300331   1978-01-01 10:30:00
# 300332   1977-05-01 00:01:00
# 300333   1975-06-01 00:00:00
# 300334   1969-07-20 21:00:00
# 300335   1963-10-30 00:00:00
# Length: 300336, dtype: datetime64[ns]

# %%
## Set dataframe index to be time series
df.index = datetimeindex
df
# Out:
#                       CrimeDate CrimeTime CrimeCode               Location  \
# 2020-04-25 17:30:00  04/25/2020  17:30:00        5A       2400 SHIRLEY AVE
# 2020-04-25 02:40:00  04/25/2020  02:40:00        5A    2900 MOUNT HOLLY ST
# 2020-04-25 09:30:00  04/25/2020  09:30:00        5C          0 N JANNEY ST
# 2020-04-25 02:30:00  04/25/2020  02:30:00        4E      900 W SARATOGA ST
# 2020-04-25 15:30:00  04/25/2020  15:30:00        6C         3700 BOSTON ST
# ...                         ...       ...       ...                    ...
# 1978-01-01 10:30:00  01/01/1978  10:30:00        2A        1900 ARGONNE DR
# 1977-05-01 00:01:00  05/01/1977  00:01:00        2A          600 W 34TH ST
# 1975-06-01 00:00:00  06/01/1975  00:00:00        2A  4400 OLD FREDERICK RD
# 1969-07-20 21:00:00  07/20/1969  21:00:00        2A        5400 ROLAND AVE
# 1963-10-30 00:00:00  10/30/1963  00:00:00        2A      3100 FERNDALE AVE
#
#                         Description Inside/Outside Weapon   Post   District  \
# 2020-04-25 17:30:00        BURGLARY              I    NaN  533.0   NORTHERN
# 2020-04-25 02:40:00        BURGLARY              I    NaN  624.0  NORTHWEST
# 2020-04-25 09:30:00        BURGLARY              I    NaN  232.0  SOUTHEAST
# 2020-04-25 02:30:00  COMMON ASSAULT            NaN    NaN  712.0    WESTERN
# 2020-04-25 15:30:00         LARCENY              I    NaN  231.0  SOUTHEAST
# ...                             ...            ...    ...    ...        ...
# 1978-01-01 10:30:00            RAPE              I  OTHER  421.0  NORTHEAST
# 1977-05-01 00:01:00            RAPE              I  OTHER  531.0   NORTHERN
# 1975-06-01 00:00:00            RAPE              I  OTHER  822.0  SOUTHWEST
# 1969-07-20 21:00:00            RAPE            NaN  OTHER  534.0   NORTHERN
# 1963-10-30 00:00:00            RAPE              I  OTHER  622.0  NORTHWEST
#
#                                Neighborhood  Longitude   Latitude
# 2020-04-25 17:30:00             GREENSPRING -76.657102  39.336238
# 2020-04-25 02:40:00           WINDSOR HILLS -76.682845  39.319594
# 2020-04-25 09:30:00                 KRESSON -76.560665  39.293067
# 2020-04-25 02:30:00               POPPLETON -76.632368  39.292449
# 2020-04-25 15:30:00  CANTON INDUSTRIAL AREA -76.565150  39.277050
# ...                                     ...        ...        ...
# 1978-01-01 10:30:00    MORGAN STATE UNIVERS -76.582056  39.340492
# 1977-05-01 00:01:00              WYMAN PARK -76.626880  39.328817
# 1975-06-01 00:00:00                 UPLANDS -76.691297  39.289582
# 1969-07-20 21:00:00             ROLAND PARK -76.635300  39.358898
# 1963-10-30 00:00:00             HOWARD PARK -76.702636  39.326875
#
# [300336 rows x 12 columns]

# %%
## Save a copy of the original dataframe (IF IT DOESN"T ALREADY EXIST)
if 'df_orig' not in locals():
    print('creating df_orig')
    df_orig = df.copy()
else:
    print('df_orig already exists')
df_orig.head()
# Out:
# creating df_orig
#                       CrimeDate CrimeTime CrimeCode             Location  \
# 2020-04-25 17:30:00  04/25/2020  17:30:00        5A     2400 SHIRLEY AVE
# 2020-04-25 02:40:00  04/25/2020  02:40:00        5A  2900 MOUNT HOLLY ST
# 2020-04-25 09:30:00  04/25/2020  09:30:00        5C        0 N JANNEY ST
# 2020-04-25 02:30:00  04/25/2020  02:30:00        4E    900 W SARATOGA ST
# 2020-04-25 15:30:00  04/25/2020  15:30:00        6C       3700 BOSTON ST
#
#                         Description Inside/Outside Weapon   Post   District  \
# 2020-04-25 17:30:00        BURGLARY              I    NaN  533.0   NORTHERN
# 2020-04-25 02:40:00        BURGLARY              I    NaN  624.0  NORTHWEST
# 2020-04-25 09:30:00        BURGLARY              I    NaN  232.0  SOUTHEAST
# 2020-04-25 02:30:00  COMMON ASSAULT            NaN    NaN  712.0    WESTERN
# 2020-04-25 15:30:00         LARCENY              I    NaN  231.0  SOUTHEAST
#
#                                Neighborhood  Longitude   Latitude
# 2020-04-25 17:30:00             GREENSPRING -76.657102  39.336238
# 2020-04-25 02:40:00           WINDSOR HILLS -76.682845  39.319594
# 2020-04-25 09:30:00                 KRESSON -76.560665  39.293067
# 2020-04-25 02:30:00               POPPLETON -76.632368  39.292449
# 2020-04-25 15:30:00  CANTON INDUSTRIAL AREA -76.565150  39.277050

# %%
# ## Identify columns to drop/keep
keep_cols = ['Description','Longitude','Latitude','District','Neighborhood']

##  Remake df from df_org using keep_cols
df = df_orig[keep_cols].copy()
df
# Out:
#                         Description  Longitude   Latitude   District  \
# 2020-04-25 17:30:00        BURGLARY -76.657102  39.336238   NORTHERN
# 2020-04-25 02:40:00        BURGLARY -76.682845  39.319594  NORTHWEST
# 2020-04-25 09:30:00        BURGLARY -76.560665  39.293067  SOUTHEAST
# 2020-04-25 02:30:00  COMMON ASSAULT -76.632368  39.292449    WESTERN
# 2020-04-25 15:30:00         LARCENY -76.565150  39.277050  SOUTHEAST
# ...                             ...        ...        ...        ...
# 1978-01-01 10:30:00            RAPE -76.582056  39.340492  NORTHEAST
# 1977-05-01 00:01:00            RAPE -76.626880  39.328817   NORTHERN
# 1975-06-01 00:00:00            RAPE -76.691297  39.289582  SOUTHWEST
# 1969-07-20 21:00:00            RAPE -76.635300  39.358898   NORTHERN
# 1963-10-30 00:00:00            RAPE -76.702636  39.326875  NORTHWEST
#
#                                Neighborhood
# 2020-04-25 17:30:00             GREENSPRING
# 2020-04-25 02:40:00           WINDSOR HILLS
# 2020-04-25 09:30:00                 KRESSON
# 2020-04-25 02:30:00               POPPLETON
# 2020-04-25 15:30:00  CANTON INDUSTRIAL AREA
# ...                                     ...
# 1978-01-01 10:30:00    MORGAN STATE UNIVERS
# 1977-05-01 00:01:00              WYMAN PARK
# 1975-06-01 00:00:00                 UPLANDS
# 1969-07-20 21:00:00             ROLAND PARK
# 1963-10-30 00:00:00             HOWARD PARK
#
# [300336 rows x 5 columns]

# %%
## Inspect the value_counts for the different types of crimes
val_counts = df['Description'].value_counts(1).to_frame()
# display with an inline-barplot inside your df
val_counts.style.bar()
# Out:
# <style  type="text/css" >
# #T_ea879b86_13ea_11eb_a4f9_acde48001122row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_ea879b86_13ea_11eb_a4f9_acde48001122row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 73.3%, transparent 73.3%);
#         }#T_ea879b86_13ea_11eb_a4f9_acde48001122row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 63.5%, transparent 63.5%);
#         }#T_ea879b86_13ea_11eb_a4f9_acde48001122row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.4%, transparent 58.4%);
#         }#T_ea879b86_13ea_11eb_a4f9_acde48001122row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.7%, transparent 47.7%);
#         }#T_ea879b86_13ea_11eb_a4f9_acde48001122row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 38.2%, transparent 38.2%);
#         }#T_ea879b86_13ea_11eb_a4f9_acde48001122row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 30.4%, transparent 30.4%);
#         }#T_ea879b86_13ea_11eb_a4f9_acde48001122row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.1%, transparent 6.1%);
#         }#T_ea879b86_13ea_11eb_a4f9_acde48001122row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.1%, transparent 4.1%);
#         }#T_ea879b86_13ea_11eb_a4f9_acde48001122row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.8%, transparent 2.8%);
#         }#T_ea879b86_13ea_11eb_a4f9_acde48001122row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.0%, transparent 2.0%);
#         }#T_ea879b86_13ea_11eb_a4f9_acde48001122row11_col0,#T_ea879b86_13ea_11eb_a4f9_acde48001122row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.0%, transparent 1.0%);
#         }#T_ea879b86_13ea_11eb_a4f9_acde48001122row13_col0{
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_ea879b86_13ea_11eb_a4f9_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row0" class="row_heading level0 row0" >LARCENY</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row0_col0" class="data row0 col0" >0.223583</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row1" class="row_heading level0 row1" >COMMON ASSAULT</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row1_col0" class="data row1 col0" >0.165148</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row2" class="row_heading level0 row2" >BURGLARY</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row2_col0" class="data row2 col0" >0.143539</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row3" class="row_heading level0 row3" >LARCENY FROM AUTO</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row3_col0" class="data row3 col0" >0.132375</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row4" class="row_heading level0 row4" >AGG. ASSAULT</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row4_col0" class="data row4 col0" >0.108901</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row5" class="row_heading level0 row5" >AUTO THEFT</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row5_col0" class="data row5 col0" >0.088088</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row6" class="row_heading level0 row6" >ROBBERY - STREET</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row6_col0" class="data row6 col0" >0.070901</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row7" class="row_heading level0 row7" >ROBBERY - COMMERCIAL</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row7_col0" class="data row7 col0" >0.017687</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row8" class="row_heading level0 row8" >SHOOTING</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row8_col0" class="data row8 col0" >0.013282</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row9" class="row_heading level0 row9" >ROBBERY - RESIDENCE</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row9_col0" class="data row9 col0" >0.010388</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row10" class="row_heading level0 row10" >ROBBERY - CARJACKING</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row10_col0" class="data row10 col0" >0.008767</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row11" class="row_heading level0 row11" >HOMICIDE</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row11_col0" class="data row11 col0" >0.006513</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row12" class="row_heading level0 row12" >RAPE</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row12_col0" class="data row12 col0" >0.006499</td>
#             </tr>
#             <tr>
#                         <th id="T_ea879b86_13ea_11eb_a4f9_acde48001122level0_row13" class="row_heading level0 row13" >ARSON</th>
#                         <td id="T_ea879b86_13ea_11eb_a4f9_acde48001122row13_col0" class="data row13 col0" >0.004328</td>
#             </tr>
#     </tbody></table>

# %%
## Lets get just Shootings in a new df
group_df = df.groupby('Description').get_group('SHOOTING')
group_df
# Out:
#                     Description  Longitude   Latitude   District  \
# 2020-04-25 16:09:00    SHOOTING -76.623695  39.288378    CENTRAL
# 2020-04-24 15:59:00    SHOOTING -76.584030  39.312696    EASTERN
# 2020-04-22 22:30:00    SHOOTING -76.674078  39.273023  SOUTHWEST
# 2020-04-22 17:49:00    SHOOTING -76.581519  39.298946    EASTERN
# 2020-04-22 17:55:00    SHOOTING -76.639655  39.291300    WESTERN
# ...                         ...        ...        ...        ...
# 2014-01-05 16:30:00    SHOOTING -76.688085  39.296987  SOUTHWEST
# 2014-01-05 19:41:00    SHOOTING -76.634616  39.300554    CENTRAL
# 2014-01-03 14:32:00    SHOOTING -76.645355  39.289607    WESTERN
# 2014-01-01 17:35:00    SHOOTING -76.672260  39.350624  NORTHWEST
# 2014-01-01 22:31:00    SHOOTING -76.555139  39.354011  NORTHEAST
#
#                              Neighborhood
# 2020-04-25 16:09:00  UNIVERSITY OF MARYLA
# 2020-04-24 15:59:00    SOUTH CLIFTON PARK
# 2020-04-22 22:30:00           SAINT AGNES
# 2020-04-22 17:49:00       MILTON-MONTFORD
# 2020-04-22 17:55:00       FRANKLIN SQUARE
# ...                                   ...
# 2014-01-05 16:30:00        ROGNEL HEIGHTS
# 2014-01-05 19:41:00                 UPTON
# 2014-01-03 14:32:00       FRANKLIN SQUARE
# 2014-01-01 17:35:00  CENTRAL PARK HEIGHTS
# 2014-01-01 22:31:00       GLENHAM-BELFORD
#
# [3989 rows x 5 columns]

# %%
## Make a new SHOOTING column that is an integer
crime ="SHOOTING"
group_df[crime] = (group_df['Description']==crime).astype(int)
group_df
# Out:
#                     Description  Longitude   Latitude   District  \
# 2020-04-25 16:09:00    SHOOTING -76.623695  39.288378    CENTRAL
# 2020-04-24 15:59:00    SHOOTING -76.584030  39.312696    EASTERN
# 2020-04-22 22:30:00    SHOOTING -76.674078  39.273023  SOUTHWEST
# 2020-04-22 17:49:00    SHOOTING -76.581519  39.298946    EASTERN
# 2020-04-22 17:55:00    SHOOTING -76.639655  39.291300    WESTERN
# ...                         ...        ...        ...        ...
# 2014-01-05 16:30:00    SHOOTING -76.688085  39.296987  SOUTHWEST
# 2014-01-05 19:41:00    SHOOTING -76.634616  39.300554    CENTRAL
# 2014-01-03 14:32:00    SHOOTING -76.645355  39.289607    WESTERN
# 2014-01-01 17:35:00    SHOOTING -76.672260  39.350624  NORTHWEST
# 2014-01-01 22:31:00    SHOOTING -76.555139  39.354011  NORTHEAST
#
#                              Neighborhood  SHOOTING
# 2020-04-25 16:09:00  UNIVERSITY OF MARYLA         1
# 2020-04-24 15:59:00    SOUTH CLIFTON PARK         1
# 2020-04-22 22:30:00           SAINT AGNES         1
# 2020-04-22 17:49:00       MILTON-MONTFORD         1
# 2020-04-22 17:55:00       FRANKLIN SQUARE         1
# ...                                   ...       ...
# 2014-01-05 16:30:00        ROGNEL HEIGHTS         1
# 2014-01-05 19:41:00                 UPTON         1
# 2014-01-03 14:32:00       FRANKLIN SQUARE         1
# 2014-01-01 17:35:00  CENTRAL PARK HEIGHTS         1
# 2014-01-01 22:31:00       GLENHAM-BELFORD         1
#
# [3989 rows x 6 columns]

# %%
## Get list of crimes to iterate through
crimes = df['Description'].unique()
crimes
# Out:
# array(['BURGLARY', 'COMMON ASSAULT', 'LARCENY', 'ROBBERY - STREET',
#        'AUTO THEFT', 'AGG. ASSAULT', 'LARCENY FROM AUTO', 'SHOOTING',
#        'ROBBERY - RESIDENCE', 'ROBBERY - COMMERCIAL', 'ARSON', 'HOMICIDE',
#        'ROBBERY - CARJACKING', 'RAPE'], dtype=object)

# %%
## make a dict of all crime types' DataFrames 
CRIMES = {}

## For each crime type
for crime in crimes:
    ## Get the group df
    group_df = df.groupby('Description').get_group(crime)

    ## Create a new column for that crime as we did for SHOOTINGS above
    group_df[crime] = (group_df['Description']==crime).astype(int)

    ## Save the group_df into the CRIMES dict
    CRIMES[crime] = group_df[crime]
    
## Display the keys
CRIMES.keys()
# Out:
# dict_keys(['BURGLARY', 'COMMON ASSAULT', 'LARCENY', 'ROBBERY - STREET', 'AUTO THEFT', 'AGG. ASSAULT', 'LARCENY FROM AUTO', 'SHOOTING', 'ROBBERY - RESIDENCE', 'ROBBERY - COMMERCIAL', 'ARSON', 'HOMICIDE', 'ROBBERY - CARJACKING', 'RAPE'])

# %%
CRIMES['LARCENY']
# Out:
# 2020-04-25 15:30:00    1
# 2020-04-25 18:00:00    1
# 2020-04-25 18:50:00    1
# 2020-04-25 16:00:00    1
# 2020-04-25 11:20:00    1
#                       ..
# 2014-01-01 00:00:00    1
# 2014-01-01 23:00:00    1
# 2014-01-01 12:56:00    1
# 2014-01-01 15:00:00    1
# 2014-01-01 01:03:00    1
# Name: LARCENY, Length: 67150, dtype: int64

# %% [markdown]
# # Visualizing Time Series

# %%
## Check out SHOOTING key
ts = CRIMES['SHOOTING']#['SHOOTING']
ts
# Out:
# 2020-04-25 16:09:00    1
# 2020-04-24 15:59:00    1
# 2020-04-22 22:30:00    1
# 2020-04-22 17:49:00    1
# 2020-04-22 17:55:00    1
#                       ..
# 2014-01-05 16:30:00    1
# 2014-01-05 19:41:00    1
# 2014-01-03 14:32:00    1
# 2014-01-01 17:35:00    1
# 2014-01-01 22:31:00    1
# Name: SHOOTING, Length: 3989, dtype: int64

# %%
## Plot shooting
ts.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# > #### Q: What went wrong? What are we looking at?

# %% [markdown]
# ## Resampling Time Series

# %%
## Resample to daily data
ts= ts.resample("D").sum()
ts.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Time series Frequencies

# %% [markdown]
# #### Pandas Frequency Aliases

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases
#
#
# |Alias	| Description|
# | --- | --- |
# |B |	business day frequency|
# |C |	custom business day frequency|
# |D |	calendar day frequency|
# |W |	weekly frequency|
# |M |	month end frequency|
# |SM |	semi-month end frequency (15th and end of month)|
# |BM |	business month end frequency|
# |CBM |	custom business month end frequency|
# |MS |	month start frequency|
# |SMS |	semi-month start frequency (1st and 15th)|
# |BMS |	business month start frequency|
# |CBMS |	custom business month start frequency|
# |Q |	quarter end frequency|
# |BQ |	business quarter end frequency|
# |QS |	quarter start frequency|
# |BQS |	business quarter start frequency|
# |A, Y |	year end frequency|
# |BA, BY |	business year end frequency|
# |AS, YS |	year start frequency|
# |BAS, BYS |	business year start frequency|
# |BH | business hour frequency|
# |H | hourly frequency|
# |T |  min	minutely frequency|
# |S | secondly frequency|
# |L |  ms	milliseconds|
# |U |  us	microseconds|
# |N | nanoseconds|

# %% [markdown]
# #### Compare Resampled ts

# %%
## Plot the same ts as different frequencies
## Specify freq codes
freq_codes = ['D','3D','W','M','Q','A']

## select ts from CRIMES
ts = CRIMES['SHOOTING']#['SHOOTING']

## For each freq code, resample and plot
for freq in freq_codes:
    
    ## Create a figure
    fig,ax = plt.subplots()
    
    ## Resample ts and plot
    ts.resample(freq).sum().plot(marker='.',title=f"Freq={freq}")

# %%
## Repeat the above loop,but plot it all on one figure
## Specify freq codes
freq_codes = ['D','3D','W','M','Q']#,'A']

## select ts from CRIMES
ts = CRIMES['SHOOTING']#['SHOOTING']
fig,ax = plt.subplots()

## For each freq code, resample and plot
for freq in freq_codes:
    
    ts.resample(freq).sum().plot(marker='.',label=f"Freq={freq}",ax=ax)
    
## Move the legend to OUTSIDE the plot    
ax.legend(bbox_to_anchor=[1.01,1.01],loc='upper left')

# %% [markdown]
# ## Visualize all CRIMES as "D" Freq

# %% [markdown]
# > **Loop through CRIMES and resample and plot all crimes**

# %%
## Plot all crimes the same way
fig, ax = plt.subplots()
for crime,ts in CRIMES.items():
    
    ts.resample('D').sum().plot(label=crime)
    
ax.legend(bbox_to_anchor=[1.05,1.0])

# %% [markdown]
# ## Slicing With Time Series

# %% [markdown]
# - Make sure you're index is sorted first'
# - Feed in 2 dates as strings for slicing.
# - Always use .loc when slicing dates

# %%
## Slice 2014:
ts = CRIMES['SHOOTING'].resample('D').sum()
ts
# Out:
# 2014-01-01    2
# 2014-01-02    0
# 2014-01-03    1
# 2014-01-04    0
# 2014-01-05    2
#              ..
# 2020-04-21    3
# 2020-04-22    5
# 2020-04-23    0
# 2020-04-24    1
# 2020-04-25    1
# Name: SHOOTING, Length: 2307, dtype: int64

# %% [markdown]
# ## Using Dictionaries for Time Series preprocessing

# %%
## Save all crimes from 2014 on with freq=D in new TS dict
TS= {}
## For each crime
for crime,ts in CRIMES.items():
    
    ## Resample and slice and save ts
    TS[crime] = ts.sort_index().loc['2014':].resample('D').sum()
    
TS.keys()
# Out:
# dict_keys(['BURGLARY', 'COMMON ASSAULT', 'LARCENY', 'ROBBERY - STREET', 'AUTO THEFT', 'AGG. ASSAULT', 'LARCENY FROM AUTO', 'SHOOTING', 'ROBBERY - RESIDENCE', 'ROBBERY - COMMERCIAL', 'ARSON', 'HOMICIDE', 'ROBBERY - CARJACKING', 'RAPE'])

# %%
## Check shooting
TS['SHOOTING']
# Out:
# 2014-01-01    2
# 2014-01-02    0
# 2014-01-03    1
# 2014-01-04    0
# 2014-01-05    2
#              ..
# 2020-04-21    3
# 2020-04-22    5
# 2020-04-23    0
# 2020-04-24    1
# 2020-04-25    1
# Freq: D, Name: SHOOTING, Length: 2307, dtype: int64

# %% [markdown]
# ### Visualize all ts with the differnet requency codes

# %%
## Plot the same ts as different frequencies
freq_codes = ['D','3D','W','M','Q']

for freq in freq_codes:
    
    fig, ax = plt.subplots()

    for crime,ts in TS.items():
        ts.loc['2015':'2019'].resample(freq).sum().plot(title=f"Freq Code = {freq}",ax=ax)
        
    ax.legend(bbox_to_anchor=(1.05,1),loc='upper left')

# %% [markdown]
# ### Save Final TS and `ts_df`

# %%
## Concatenate the TS dict to a single DataFrame and display .head()
ts_df = pd.concat(TS,axis=1)
ts_df.head()
# Out:
#             BURGLARY  COMMON ASSAULT  LARCENY  ROBBERY - STREET  AUTO THEFT  \
# 2014-01-01        20              19       34                 8           9
# 2014-01-02        28              23       26                 4           7
# 2014-01-03        13              17       16                 2           3
# 2014-01-04        20              23       23                 7          14
# 2014-01-05        14              22       19                10          11
#
#             AGG. ASSAULT  LARCENY FROM AUTO  SHOOTING  ROBBERY - RESIDENCE  \
# 2014-01-01            22                 15         2                    1
# 2014-01-02             6                 10         0                    1
# 2014-01-03            11                  6         1                    1
# 2014-01-04            14                 15         0                    1
# 2014-01-05             9                 13         2                    1
#
#             ROBBERY - COMMERCIAL  ARSON  HOMICIDE  ROBBERY - CARJACKING  RAPE
# 2014-01-01                     2    NaN       2.0                   NaN   4.0
# 2014-01-02                     1    NaN       3.0                   1.0   0.0
# 2014-01-03                     1    NaN       1.0                   0.0   0.0
# 2014-01-04                     1    NaN       0.0                   0.0   0.0
# 2014-01-05                     0    NaN       0.0                   2.0   1.0

# %%
## Check For Null Values
nulls = ts_df.isna().sum()
display(nulls)

## Save List of columns with null values
null_cols = nulls[nulls>0].index
null_cols
# Out:
# BURGLARY                0
# COMMON ASSAULT          0
# LARCENY                 0
# ROBBERY - STREET        0
# AUTO THEFT              0
# AGG. ASSAULT            0
# LARCENY FROM AUTO       0
# SHOOTING                0
# ROBBERY - RESIDENCE     0
# ROBBERY - COMMERCIAL    0
# ARSON                   6
# HOMICIDE                2
# ROBBERY - CARJACKING    4
# RAPE                    6
# dtype: int64
# Index(['ARSON', 'HOMICIDE', 'ROBBERY - CARJACKING', 'RAPE'], dtype='object')

# %%
## Show rows with null values
ts_df[ts_df.isna().sum(axis=1) > 0][null_cols]
# Out:
#             ARSON  HOMICIDE  ROBBERY - CARJACKING  RAPE
# 2014-01-01    NaN       2.0                   NaN   4.0
# 2014-01-02    NaN       3.0                   1.0   0.0
# 2014-01-03    NaN       1.0                   0.0   0.0
# 2014-01-04    NaN       0.0                   0.0   0.0
# 2014-01-05    NaN       0.0                   2.0   1.0
# 2020-04-20    0.0       0.0                   0.0   NaN
# 2020-04-21    2.0       1.0                   0.0   NaN
# 2020-04-22    0.0       1.0                   1.0   NaN
# 2020-04-23    0.0       1.0                   NaN   NaN
# 2020-04-24    1.0       NaN                   NaN   NaN
# 2020-04-25    NaN       NaN                   NaN   NaN

# %%
## save index of null rows to compare before and after
null_rows = ts_df[ts_df.isna().sum(axis=1) >0].index
null_rows
# Out:
# DatetimeIndex(['2014-01-01', '2014-01-02', '2014-01-03', '2014-01-04',
#                '2014-01-05', '2020-04-20', '2020-04-21', '2020-04-22',
#                '2020-04-23', '2020-04-24', '2020-04-25'],
#               dtype='datetime64[ns]', freq=None)

# %%
## Slice out the rows that contained null values in the null columns
ts_df.loc[null_rows,null_cols]
# Out:
#             ARSON  HOMICIDE  ROBBERY - CARJACKING  RAPE
# 2014-01-01    NaN       2.0                   NaN   4.0
# 2014-01-02    NaN       3.0                   1.0   0.0
# 2014-01-03    NaN       1.0                   0.0   0.0
# 2014-01-04    NaN       0.0                   0.0   0.0
# 2014-01-05    NaN       0.0                   2.0   1.0
# 2020-04-20    0.0       0.0                   0.0   NaN
# 2020-04-21    2.0       1.0                   0.0   NaN
# 2020-04-22    0.0       1.0                   1.0   NaN
# 2020-04-23    0.0       1.0                   NaN   NaN
# 2020-04-24    1.0       NaN                   NaN   NaN
# 2020-04-25    NaN       NaN                   NaN   NaN

# %% [markdown]
# > More columns would benefit from ffill than bfill so we are going to ffill and then dropna to remove the few days at the beginning of 2014 without data

# %%
## FFill null values
ts_df.ffill(inplace=True)

## chekc for nulls
ts_df.loc[null_rows,null_cols]
# Out:
#             ARSON  HOMICIDE  ROBBERY - CARJACKING  RAPE
# 2014-01-01    NaN       2.0                   NaN   4.0
# 2014-01-02    NaN       3.0                   1.0   0.0
# 2014-01-03    NaN       1.0                   0.0   0.0
# 2014-01-04    NaN       0.0                   0.0   0.0
# 2014-01-05    NaN       0.0                   2.0   1.0
# 2020-04-20    0.0       0.0                   0.0   1.0
# 2020-04-21    2.0       1.0                   0.0   1.0
# 2020-04-22    0.0       1.0                   1.0   1.0
# 2020-04-23    0.0       1.0                   1.0   1.0
# 2020-04-24    1.0       1.0                   1.0   1.0
# 2020-04-25    1.0       1.0                   1.0   1.0

# %%
## Drop remaining nulls
ts_df.bfill(inplace=True)
ts_df.loc[null_rows,null_cols]
# Out:
#             ARSON  HOMICIDE  ROBBERY - CARJACKING  RAPE
# 2014-01-01    2.0       2.0                   1.0   4.0
# 2014-01-02    2.0       3.0                   1.0   0.0
# 2014-01-03    2.0       1.0                   0.0   0.0
# 2014-01-04    2.0       0.0                   0.0   0.0
# 2014-01-05    2.0       0.0                   2.0   1.0
# 2020-04-20    0.0       0.0                   0.0   1.0
# 2020-04-21    2.0       1.0                   0.0   1.0
# 2020-04-22    0.0       1.0                   1.0   1.0
# 2020-04-23    0.0       1.0                   1.0   1.0
# 2020-04-24    1.0       1.0                   1.0   1.0
# 2020-04-25    1.0       1.0                   1.0   1.0

# %%
## Final null check
ts_df.isna().sum()
# Out:
# BURGLARY                0
# COMMON ASSAULT          0
# LARCENY                 0
# ROBBERY - STREET        0
# AUTO THEFT              0
# AGG. ASSAULT            0
# LARCENY FROM AUTO       0
# SHOOTING                0
# ROBBERY - RESIDENCE     0
# ROBBERY - COMMERCIAL    0
# ARSON                   0
# HOMICIDE                0
# ROBBERY - CARJACKING    0
# RAPE                    0
# dtype: int64

# %%
## Save df to csv for time series modeling next class
ts_df.to_csv('baltimore_crime_2020_ts_041320pt.csv')

# %% [markdown]
# # Time Series Trends

# %% [markdown]
# ## Types of Trends

# %% [markdown]
# <img src="https://raw.githubusercontent.com/learn-co-students/dsc-removing-trends-online-ds-ft-100719/master/images/new_trendseasonal.png" width=80%>

# %% [markdown]
# ## Stationarity

# %% [markdown]
# <div style="text-align:center;font-size:2em">Mean</div>
#
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-types-of-trends-online-ds-ft-100719/master/images/new_mean_nonstationary.png" width=70%>
# <br><br>
# <div style="text-align:center;font-size:3em">Variance</div>
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-types-of-trends-online-ds-ft-100719/master/images/new_cov_nonstationary.png" width=70%>
# </div>

# %%
## Lab Function
from statsmodels.tsa.stattools import adfuller

def stationarity_check(TS,plot=True,col=None):
    """From: https://learn.co/tracks/data-science-career-v2/module-4-a-complete-data-science-project-using-multiple-regression/working-with-time-series-data/time-series-decomposition
    """
    
    # Import adfuller
    from statsmodels.tsa.stattools import adfuller

    if col is not None:
        # Perform the Dickey Fuller Test
        dftest = adfuller(TS[col]) # change the passengers column as required 
    else:
        dftest=adfuller(TS)
 
    if plot:
        # Calculate rolling statistics
        rolmean = TS.rolling(window = 8, center = False).mean()
        rolstd = TS.rolling(window = 8, center = False).std()

        #Plot rolling statistics:
        fig = plt.figure(figsize=(12,6))
        orig = plt.plot(TS, color='blue',label='Original')
        mean = plt.plot(rolmean, color='red', label='Rolling Mean')
        std = plt.plot(rolstd, color='black', label = 'Rolling Std')
        plt.legend(loc='best')
        plt.title('Rolling Mean & Standard Deviation')
#     plt.show(block=False)
    
    # Print Dickey-Fuller test results
    print ('Results of Dickey-Fuller Test:')

    dfoutput = pd.Series(dftest[0:4],
                         index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
        
    dfoutput['sig'] = dfoutput['p-value']<.05
    display (dfoutput.round(3))
    
    return dfoutput

# %%
## Save LARCENY for 2017-End as our ts
ts = ts_df['LARCENY'].loc['2017':]
stationarity_check(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -1.058
# p-value                           0.731
# #Lags Used                       21.000
# Number of Observations Used    1189.000
# Critical Value (1%)              -3.436
# Critical Value (5%)              -2.864
# Critical Value (10%)             -2.568
# sig                               0.000
# dtype: float64
# Test Statistic                   -1.058381
# p-value                           0.731381
# #Lags Used                       21.000000
# Number of Observations Used    1189.000000
# Critical Value (1%)              -3.435862
# Critical Value (5%)              -2.863974
# Critical Value (10%)             -2.568066
# sig                               0.000000
# dtype: float64

# %% [markdown]
# > Since our AD Fuller Test p-value is > .05 we conclude that we have non-stationary data. So now what??

# %% [markdown]
# # Removing Trends

# %% [markdown]
# #### Trend Removal Methods
# - Log-Transformation (`np.log`)
# - Differencing (`.diff()`)
# - Subtract Rolling Mean (`ts-ts.rolling().mean()`)
# - Subtract Exponentially-Weighted Mean (`ts-ts.ewm().mean()`)
# - Seasonal Decomposition (`from statsmodels.tsa.seasonal import seasonal_decompose`
# )

# %%
## Simpler Version of ADfullter func
def adfuller_test_df(ts):
    """Returns the AD Fuller Test Results and p-values for the null hypothesis
    that there the data is non-stationary (that there is a unit root in the data)"""
    df_res = adfuller(ts)
    names = ['Test Statistic','p-value','#Lags Used','# of Observations Used']
    res  = dict(zip(names,df_res[:4]))
    res['p<.05'] = res['p-value']<.05
    res['Stationary?'] = res['p<.05']
    
    return pd.DataFrame(res,index=['AD Fuller Results'])

# %%
## Plot ts and show adfuller results
ts.plot()
adfuller_test_df(ts)
# Out:
#                    Test Statistic   p-value  #Lags Used  \
# AD Fuller Results       -1.058381  0.731381          21
#
#                    # of Observations Used  p<.05  Stationary?
# AD Fuller Results                    1189  False        False

# %%
## Log Transform
ts3 = np.log(ts)
ts3.plot()
adfuller_test_df(ts3)
# Out:
#                    Test Statistic   p-value  #Lags Used  \
# AD Fuller Results       -0.103871  0.949052          20
#
#                    # of Observations Used  p<.05  Stationary?
# AD Fuller Results                    1190  False        False

# %%
## Differencing 
ts0 = ts.diff().dropna()
ts0.plot()
adfuller_test_df(ts0)
# Out:
#                    Test Statistic       p-value  #Lags Used  \
# AD Fuller Results      -12.550478  2.211650e-23          20
#
#                    # of Observations Used  p<.05  Stationary?
# AD Fuller Results                    1189   True         True

# %%
## Differencing 
ts0 = ts.diff().dropna()
ts0.plot()
adfuller_test_df(ts0)
# Out:
#                    Test Statistic       p-value  #Lags Used  \
# AD Fuller Results      -12.550478  2.211650e-23          20
#
#                    # of Observations Used  p<.05  Stationary?
# AD Fuller Results                    1189   True         True

# %%
## Subtract Rolling mean
ts2 = (ts - ts.rolling(3).mean()).dropna()
ts2.plot()
adfuller_test_df(ts2)
# Out:
#                    Test Statistic       p-value  #Lags Used  \
# AD Fuller Results      -13.004946  2.639680e-24          19
#
#                    # of Observations Used  p<.05  Stationary?
# AD Fuller Results                    1189   True         True

# %%
## Subtract Exponentially Weight Mean Rolling mean
ts4 = (ts - ts.ewm(halflife=7).mean()).dropna()
ts4.plot()
adfuller_test_df(ts4)
# Out:
#                    Test Statistic       p-value  #Lags Used  \
# AD Fuller Results       -7.241487  1.879287e-10          20
#
#                    # of Observations Used  p<.05  Stationary?
# AD Fuller Results                    1190   True         True

# %% [markdown]
# ## Seasonal Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomp = seasonal_decompose(ts,model='mul')
decomp.plot();

# %%
## Get ADFuller Results for seasonal component
adfuller_test_df(decomp.seasonal)
# Out:
#                    Test Statistic  p-value  #Lags Used  \
# AD Fuller Results   -8.093449e+15      0.0          23
#
#                    # of Observations Used  p<.05  Stationary?
# AD Fuller Results                    1187   True         True

# %%
## Get ADFuller Results for trend component
adfuller_test_df(decomp.trend.dropna())
# Out:
#                    Test Statistic   p-value  #Lags Used  \
# AD Fuller Results       -0.447564  0.901849          21
#
#                    # of Observations Used  p<.05  Stationary?
# AD Fuller Results                    1183  False        False

# %%
## Get ADFuller Results for resid component
adfuller_test_df(decomp.resid.dropna())
# Out:
#                    Test Statistic       p-value  #Lags Used  \
# AD Fuller Results      -17.709945  3.505956e-30          12
#
#                    # of Observations Used  p<.05  Stationary?
# AD Fuller Results                    1192   True         True

# %% [markdown]
# # APPENDIX

# %% [markdown]
# ### Date Str Formatting

# %% [markdown]
# Formatting follows the Python datetime <strong><a href='http://strftime.org/'>strftime</a></strong> codes.<br>
# The following examples are based on <tt>datetime.datetime(2001, 2, 3, 16, 5, 6)</tt>:
# <br><br>
#
# <table style="display: inline-block">
# <tr><th>CODE</th><th>MEANING</th><th>EXAMPLE</th><tr>
# <tr><td>%Y</td><td>Year with century as a decimal number.</td><td>2001</td></tr>
# <tr><td>%y</td><td>Year without century as a zero-padded decimal number.</td><td>01</td></tr>
# <tr><td>%m</td><td>Month as a zero-padded decimal number.</td><td>02</td></tr>
# <tr><td>%B</td><td>Month as locale’s full name.</td><td>February</td></tr>
# <tr><td>%b</td><td>Month as locale’s abbreviated name.</td><td>Feb</td></tr>
# <tr><td>%d</td><td>Day of the month as a zero-padded decimal number.</td><td>03</td></tr>
# <tr><td>%A</td><td>Weekday as locale’s full name.</td><td>Saturday</td></tr>
# <tr><td>%a</td><td>Weekday as locale’s abbreviated name.</td><td>Sat</td></tr>
# <tr><td>%H</td><td>Hour (24-hour clock) as a zero-padded decimal number.</td><td>16</td></tr>
# <tr><td>%I</td><td>Hour (12-hour clock) as a zero-padded decimal number.</td><td>04</td></tr>
# <tr><td>%p</td><td>Locale’s equivalent of either AM or PM.</td><td>PM</td></tr>
# <tr><td>%M</td><td>Minute as a zero-padded decimal number.</td><td>05</td></tr>
# <tr><td>%S</td><td>Second as a zero-padded decimal number.</td><td>06</td></tr>
# </table>
# <table style="display: inline-block">
# <tr><th>CODE</th><th>MEANING</th><th>EXAMPLE</th><tr>
# <tr><td>%#m</td><td>Month as a decimal number. (Windows)</td><td>2</td></tr>
# <tr><td>%-m</td><td>Month as a decimal number. (Mac/Linux)</td><td>2</td></tr>
# <tr><td>%#x</td><td>Long date</td><td>Saturday, February 03, 2001</td></tr>
# <tr><td>%#c</td><td>Long date and time</td><td>Saturday, February 03, 2001 16:05:06</td></tr>
# </table>
