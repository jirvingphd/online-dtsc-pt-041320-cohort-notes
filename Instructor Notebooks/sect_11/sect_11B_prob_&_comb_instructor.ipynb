# %% [markdown]
# <div style="color:red;font-weight:bold"> Note to Jeff: You may want to review the sections marked with the notebook emojis 📖  and DEFINITELY should read any red text notes</div>
#
#
# - **Summary of Last Class & Beginning This One:**
#     - We covered the first half of thus notebook (Sect 11A) and made it through [ORIGINAL END OF 06/12 Study Group](#ORIGINAL-END-OF-06/12-Study-Group).
#     - but you should recap some material for them so start a bit earlier at:
#         - [Sect 11B: Conditional Probability & Law of Total Probability - 06/16/20](#Sect-11B:-Conditional-Probability-&-Law-of-Total-Probability---06/16/20)
#
#     - The study group recording is located [here](https://youtu.be/whoXm_6jU8E), in case you'd find that helpful.
#
#
# - **Note: The intro to section 12 at the end is 1000% optional.**
#
#
# <br>
# <div style="color:red;font-weight:bold">Students questions document</div>
#
# - Students queue up questions in the [Questions Doc](https://docs.google.com/document/d/196yIMNSRSRspBdBmjHq7vMhFF-YdpvkyYEHYV5nm8xg/edit?usp=sharing), so you should take a peek at that at the beginning of class
# ___

# %% [markdown]
# # Sect 11A: Combinatorics & Probability (last S.G.)

# %% [markdown]
# - Study Group for: online-ds-pt-041320
#
# - 06/12/20

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# - Understand what sets are and set operations.
# - Understand what probability is and how it is calculated.
# - Understand factorials, permutations, and combinations.
#
# - **Activity: Playlist Probabilities**

# %% [markdown]
# ### Links/References:
# - Study Groups:
#     - [Reviewing Probability & Combinatorics - M3S17 [2019-07-16]](https://www.youtube.com/watch?v=UBWnkflWvmU&list=PLVoXE6pv5LIgIui2D6u0Nga3oHtQ2ogmY&index=2) - Victor
#     - [Permutations & Factorials](https://youtu.be/-tzUcmASgC8) - Jeff
#     - [Permutations/Combinations](https://www.youtube.com/watch?v=WMYnIe2f7to&feature=youtu.be) - Rafael

# %% [markdown]
# ## QUESTIONS:

# %% [markdown]
# ## Part 1: Intro to Probability

# %% [markdown]
# ### Sets

# %% [markdown]
# > A **Set**: *a well-defined collection of unique objects*.
#
# **Math notation:**
# - Define a set as $S$
# - If $x$ is an element of set $S$:
#     - $x \in S$.
# - If $x$ is not an element of set $S$:
#     - $x\notin S$.
#
# ### Subset:
# > A **Subset**: set $T$ is a subset of set $S$ if *every element* in set $T$ is also in set $S$.
#
# **Math Notation**
# - $T$ is a subset of $S$.
#     - $T \subset S$
#
# - $T$ and $S$ can be the SAME population
# - If $T$ != $S$, but $T \subset S$, called a 'proper subset'
#     - Can use notation:  $T \subsetneq S$ and $T \subseteq S$
#
# ### Universal set:
# > A **Universal Set**: The collection of all possible outcomes in a certain context or universe.
#
# **Math Notation**
# - Universal set denoted by Omega ($\Omega$)
# - Can have infinite # of elements (e.g. the set of all real numbers!)
# - Example: all possible outcomes of a 6-sided die:
#     - $\Omega = \{1,2,3,4,5,6\}$

# %% [markdown]
# ### Set operations:

# %% [markdown]
# - Data used in examples:
#
# Imagine you have two sets of numbers, say the first 4 multiples of 3 in set $S$:
#
# $ S = \{3,6,9,12\}$
#
#  and the first 4 multiples of 2 in set $T$:
#
# $ T = \{2,4,6,8\} $.

# %% [markdown]
# #### Union (combining elements)

# %% [markdown]
# - the union of $S$ and $T$ is denoted as $S \cup T$
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-intro-to-sets-online-ds-ft-100719/master/images/new_union.png" width=200>

# %% [markdown]
# #### Intersection

# %% [markdown]
# - contains all elements of $S$ that also belong to $T$.
#     - denoted as $S \cap T$.
#
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-intro-to-sets-online-ds-ft-100719/master/images/new_intersection.png" width=200>

# %% [markdown]
# #### Relative complement / difference

# %% [markdown]
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-intro-to-sets-online-ds-ft-100719/master/images/new_rel_comp.png" width=200>
#
# -  the relative complement of S contains all the elements of T that are NOT in S.
#     - relative complement of S (or $ T\backslash S $) is $\{2,4,8\}$.
#     - relative complement  of T (or $ S\backslash T $) is $\{3,9,12\}$.
#
# <!img src="https://raw.githubusercontent.com/learn-co-students/dsc-1-08-07-introduction-to-sets-online-ds-ft-021119/master/rel_comp.png" width=300>

# %% [markdown]
# #### Absolute complement

# %% [markdown]
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-intro-to-sets-online-ds-ft-100719/master/images/new_abs_comp.png" width=200>
#
#
# - The absolute complement of $S$, with respect to the Universal set $\Omega$, is the collection of the objects in $\Omega$ that don't belong to $S$.
#     -  absolute complement of $S$ is denoted as $S'$ or $S^c$.
#
# <!img src="https://raw.githubusercontent.com/learn-co-students/dsc-1-08-07-introduction-to-sets-online-ds-ft-021119/master/abs_comp.png" width=300>
#
# - Example: Let's define $\Omega$ (box around the two venn diagrams) = multiples of both 2 and 3 until 20.
#
#     - Elements of $\Omega$ are $\{2,3,4,6,8,9,10,12,14,15,16,18,20\}$.
#
#     - The absolute complement of $S$ (so $S'$ or $S^c$) is then given by $\{2,4,8,10,14,15,16,18,20\}$.

# %% [markdown]
# ### Note on Important Number Sets & Their Notation
#
# - If you define that the event "low daily number of text messages sent" means 20 or fewer text messages, the event space is defined as: $E = \{x \mid x \in \mathbb{Z}, 0 \leq x \leq 20 \}$
# - Binge-watch day:  $E = \{x \mid x \in \mathbb{R}, x \geq 6 \}$
#
# | SYMBOL | MEANING |
# | --- | --- |
# |$\emptyset$ or $\{\}$ | empty set
# |$ \mathbb{N}$ | natural numbers |
# |$\mathbb{Z}$ | integers (from Zahl, German for number). |
# |$ \mathbb{Q}$ | rational numbers (from quotient) |
# |$\mathbb{R}$  | real numbers |
# |$ \mathbb{C}$ | complex numbers |

# %% [markdown]
# ### Inclusion Exclusion principle

# %% [markdown]
# - Used to calculate the number of elements of each set and the union of all sets.
#
# - Note $|S|$ denotes the *cardinality* of S aka the number of element in S
#
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-intro-to-sets-online-ds-ft-100719/master/images/new_venn_diagram.png" width=400>
#
#
# - When combining  2 sets, the method for obtaining the union of two finite sets is given by:
#
#     - $\mid S \cup T \mid = \mid S \mid + \mid T \mid - \mid S \cap T \mid $
#
#         - Horizontal lines denote the *cardinality* of a set, which is the number of elements, considering a finite set.
# - When combining 3 sets:
#
# $\mid S \cup T\cup R \mid = \mid S \mid + \mid T \mid + \mid R \mid - \mid S \cap T \mid  -\mid S \cap R \mid - \mid R \cap T \mid  + \mid S \cap T \cap R \mid $
#
#
# - *The formula expresses the fact that the sum of the sizes of the two sets may be too large since some elements may be counted twice. For the double-counted elements, one is substracted again.*
#
# ### Empty
#  - An **empty** set has no elements
#  - denoted by $\emptyset$ or simply $\{\}$

# %% [markdown]
# ### SET OPERATIONS IN PYTHON

# %% [markdown]
#
#
# | Method        |	Equivalent |	Result |
# | ------                    | ------       | ------    |
# | s.issubset(t)             |	s <= t     | test whether every element in s is in t
# | s.issuperset(t)           |	s >= t     | test whether every element in t is in s
# | s.union(t)                |	s $\mid$ t | new set with elements from both s and t
# | s.intersection(t)         |	s & t      | new set with elements common to s and t
# | s.difference(t)           |	s - t 	   | new set with elements in s but not in t
# | s.symmetric_difference(t) |	s ^ t      | new set with elements in either s or t but not both

# %% [markdown]
# ## Probability

# %% [markdown]
# ### What is probability?

# %% [markdown]
# > **Probability is the likelihood of a specific outcome/event occuring out of all possible outcomes, expressed as a fraction between 0 and 1.**
# <!---
# Example Probability Qs:
# - How likely is it to end up with heads when flipping a coin once? (the answer here is 50% - not very surprising)
#
# - How likely is it to end up with exactly 2 x heads and 3 x tails when flipping a coin 5 times?
#
# - How likely is it to throw tails first, then heads, then tails, then heads, then tails when flipping a coin 5 times?
#
# - If you throw 5 dice, what is the probability of throwing a ["full house"](http://grail.sourceforge.net/demo/yahtzee/rules.html)?
#
# - What is the probability of drawing 2 consecutive aces from a standard deck of cards?
#
# > But how do we calculate it? ..._to be continued_...
#
# --->

# %% [markdown]
# ### Sample Space & Event Space

# %% [markdown]
# ##### Sample space:

# %% [markdown]
# $$S = \{ 1,2,3,4,5,6\}$$
# being the possible outcomes when throwing a dice.
# - Sample space =  $\Omega$

# %% [markdown]
# ##### Event space:

# %% [markdown]
# -   The **event space** is a subset of the sample space. It is the **desired outcome** of the experiment.
# $$E \subseteq S$$
# -   Example:
#     -   Throwing an odd number would lead to an event space $$E = \{ 1,3,5\}$$.

# %% [markdown]
# ### Probability of an Event

# %% [markdown]
# $$ P(E) = \frac{|E|}{|S|} $$
# probability is the number of possible preferred outcomes over the sample space / all outcomes

# %% [markdown]
# ### Law of relative frequency

# %% [markdown]
# - Limit of large infinite outcomes produce fixed numbers .
# $$ \large P(E) = \lim_{n\to\infty}\frac{S(n)}{n}$$
#     - Probability of Event E having Successful(S) outcomes for $n$ trials

# %% [markdown]
# ### Probability axioms

# %% [markdown]
# 1.  Positivity :
#
#     - Prob is always $0 <= P(E) <=1$
#
#
# 2.  Probability of a certain/guaranteed event:
#
#     - $P(S)=1$
#
#
# 3.  Additivity Union of 2 exclusive sets = sum prob of individual events happening
#
#     - If $A\cap B = \emptyset $, then $P(A\cup B) = P(A) + P(B)$

# %% [markdown]
# ### Addition law of probability

# %% [markdown]
# -   Prob of union of A and B is individual P minus intersection
#
# $$ \large P(A\cup B) = P(A) + P(B) - P(A \cap B)$$

# %% [markdown]
# ## Permutations

# %% [markdown]
# - **Permutations have to do with arranging objects.(Order is important)**
#
# > ***How many ways to arrange n elements?***
#     $$\large P(n) = n!$$

# %% [markdown]
# ### Factorials

# %% [markdown]
# The factorial of $n$ is calculated by multiplying every number below $n$ together.
#
# $$n! = n  \times (n-1) \times (n-2)\times...\times1$$
#
#
#
# **Factorial Rules/Operations:**
# - Negative numbers do not have a factorial.
# - $0! = 1$
# - $n! = (n-1)! \cdot n$
# - $(n+1)! = n! \cdot (n+1)$
#
# - $ (n+k)! = n! \cdot (n+1) \cdot (n+2) \cdot... (n+k) $
#
# - $ (n-k)! = \frac{n!}{(n-k+1)\cdot(n-k+2) \cdot ... (n-k+k) }$
# - When $n>k$:
#     - $\frac{n!}{k!} = (k+1)\cdot(k+2)\cdot...n $

# %% [markdown]
# ### Permutations of a subset / AKA Permutations without replacement

# %% [markdown]
# > ***How many ways to select $k$ elements out of a pool of $n$ objects?***
#
# $$ \large P_{k}^{n}= \dfrac{n!}{(n-k)!}$$
#
# this is known as the **$k$-permutation of $n$**

# %% [markdown]
# ### Permutations with replacement

# %% [markdown]
# $$ \large {P}_{j}^{n} = n^j $$
# - where $n$ = total number of elements
# - $j$ = number of positions to fill

# %% [markdown]
# ### Permutations with repetition

# %% [markdown]
# - Permutation where there are some elements that may appear multiple times.
#     - i.e. looking at the word TENNESSEE by itself, you can swap the 3rd and the 4th letter and have the same word. So the total number is less than $9!$.
#
#     - The solution is to divide $9!$ by the factorials for each letter that is repeated!
#     - The answer here is then (9 letters, 4 x E, 2 x N, 2 x S)
#
#     - $\dfrac{9!}{4!2!2!} = 3780$
#
# The general formula can be written as:
#
# $$\dfrac{n!}{n_1!n_2!\ldots n_j!}$$
#
# where $n_j$ stands for identical objects of type $j$ (the distinct letters in our TENNESSEE example).

# %% [markdown]
# ## Combinations

# %% [markdown]
# - How many ways can we create a subset $k$ out of $n$ objects, when order is not important?
#
#
# $$\large C_{k}^{n} = \displaystyle\binom{n}{k} = \dfrac{P_{k}^{n}}{k!}=\dfrac{ \dfrac{n!}{(n-k)!}}{k!} = \dfrac{n!}{(n-k)!k!}$$

# %% [markdown]
# ## 📖 Activity: Planning Party Playlists

# %% [markdown]
# ### Activity Pt 1: Playlist Probabilities

# %% [markdown]
# - **We are constructing a dinner party playlist for a gathering we are planning.**
#     - We asked our attendees to each provide a handful of songs they would like to be played at the dinner party.
#     - Their suggestions are saved in csvs located in the `probability_playlists/` folder
#
# - **We want the sound-scape of our dinner party to express the tastes of every single attendee, so we will allow for duplicate/repeated songs if multiple people recommended it.**

# %%
# !pip install -U fsds

from fsds.imports import *
from math import factorial
# Out:
# fsds v0.2.13 loaded.  Read the docs: https://fs-ds.readthedocs.io/en/latest/
# <style  type="text/css" >
# </style><table id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626" ><caption>Loaded Packages and Handles</caption><thead>    <tr>        <th class="col_heading level0 col0" >Handle</th>        <th class="col_heading level0 col1" >Package</th>        <th class="col_heading level0 col2" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row0_col0" class="data row0 col0" >dp</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row0_col1" class="data row0 col1" >IPython.display</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row0_col2" class="data row0 col2" >Display modules with helpful display and clearing commands.</td>
#             </tr>
#             <tr>
#                                 <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row1_col0" class="data row1 col0" >fs</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row1_col1" class="data row1 col1" >fsds</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row1_col2" class="data row1 col2" >Custom data science bootcamp student package</td>
#             </tr>
#             <tr>
#                                 <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row2_col0" class="data row2 col0" >mpl</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row2_col1" class="data row2 col1" >matplotlib</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row2_col2" class="data row2 col2" >Matplotlib's base OOP module with formatting artists</td>
#             </tr>
#             <tr>
#                                 <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row3_col0" class="data row3 col0" >plt</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row3_col1" class="data row3 col1" >matplotlib.pyplot</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row3_col2" class="data row3 col2" >Matplotlib's matlab-like plotting module</td>
#             </tr>
#             <tr>
#                                 <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row4_col0" class="data row4 col0" >np</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row4_col1" class="data row4 col1" >numpy</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row4_col2" class="data row4 col2" >scientific computing with Python</td>
#             </tr>
#             <tr>
#                                 <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row5_col0" class="data row5 col0" >pd</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row5_col1" class="data row5 col1" >pandas</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row5_col2" class="data row5 col2" >High performance data structures and tools</td>
#             </tr>
#             <tr>
#                                 <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row6_col0" class="data row6 col0" >sns</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row6_col1" class="data row6 col1" >seaborn</td>
#                         <td id="T_dd67d6b8_ae9f_11ea_a587_4865ee12e626row6_col2" class="data row6 col2" >High-level data visualization library based on matplotlib</td>
#             </tr>
#     </tbody></table>

# %%
import os,glob
datafolder = "../../Mod 2/sect_11/probability_playlists/" ## student filepath
rec_files = glob.glob(datafolder+"*.csv")

playlists = {}
for file in rec_files:
    key = os.path.basename(file).replace('_recs.csv','')
    playlists[key] = pd.read_csv(file)
playlists.keys()
# Out:
# dict_keys(['joe', 'james', 'anne', 'john', 'samantha'])

# %%
for name,playlist in playlists.items():
    display(playlist.style.set_caption(name))
# Out:
# <style  type="text/css" >
# </style><table id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626" ><caption>joe</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626row0_col0" class="data row0 col0" >Green Day</td>
#                         <td id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626row0_col1" class="data row0 col1" >Time of your Life</td>
#                         <td id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626row0_col2" class="data row0 col2" >Joe</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626row1_col0" class="data row1 col0" >B-52s</td>
#                         <td id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626row1_col1" class="data row1 col1" >Rock Lobster</td>
#                         <td id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626row1_col2" class="data row1 col2" >Joe</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626row2_col0" class="data row2 col0" >Lady GaGa</td>
#                         <td id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626row2_col1" class="data row2 col1" >Poker Face</td>
#                         <td id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626row2_col2" class="data row2 col2" >Joe</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626row3_col0" class="data row3 col0" >John Lennon</td>
#                         <td id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626row3_col1" class="data row3 col1" >Imagine</td>
#                         <td id="T_dd6d69ac_ae9f_11ea_a480_4865ee12e626row3_col2" class="data row3 col2" >Joe</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626" ><caption>james</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626row0_col0" class="data row0 col0" >Eve 6</td>
#                         <td id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626row0_col1" class="data row0 col1" >Here's to the Night</td>
#                         <td id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626row0_col2" class="data row0 col2" >James</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626row1_col0" class="data row1 col0" >Neutral Milk Hotel</td>
#                         <td id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626row1_col1" class="data row1 col1" >Into the Aeroplane Over the Sea</td>
#                         <td id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626row1_col2" class="data row1 col2" >James</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626row2_col0" class="data row2 col0" >Rilo Kiley</td>
#                         <td id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626row2_col1" class="data row2 col1" >With Arms Outstretched</td>
#                         <td id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626row2_col2" class="data row2 col2" >James</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626row3_col0" class="data row3 col0" >Red Hot Chili Peppers</td>
#                         <td id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626row3_col1" class="data row3 col1" >Otherside</td>
#                         <td id="T_dd6dbe02_ae9f_11ea_8389_4865ee12e626row3_col2" class="data row3 col2" >James</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626" ><caption>anne</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626row0_col0" class="data row0 col0" >Smashing Pumpkins</td>
#                         <td id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626row0_col1" class="data row0 col1" >Tonight, Tonight</td>
#                         <td id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626row0_col2" class="data row0 col2" >Anne</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626row1_col0" class="data row1 col0" >Black Eyed Peas</td>
#                         <td id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626row1_col1" class="data row1 col1" >Let's Get it Started</td>
#                         <td id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626row1_col2" class="data row1 col2" >Anne</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626row2_col0" class="data row2 col0" >Green Day</td>
#                         <td id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626row2_col1" class="data row2 col1" >Time of your Life</td>
#                         <td id="T_dd6e0698_ae9f_11ea_b092_4865ee12e626row2_col2" class="data row2 col2" >Anne</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626" ><caption>john</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626row0_col0" class="data row0 col0" >Black Eyed Peas</td>
#                         <td id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626row0_col1" class="data row0 col1" >Let's Get it Started</td>
#                         <td id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626row0_col2" class="data row0 col2" >John</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626row1_col0" class="data row1 col0" >Lady GaGa</td>
#                         <td id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626row1_col1" class="data row1 col1" >Poker Face</td>
#                         <td id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626row1_col2" class="data row1 col2" >John</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626row2_col0" class="data row2 col0" >Lady GaGa</td>
#                         <td id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626row2_col1" class="data row2 col1" >Bad Romance</td>
#                         <td id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626row2_col2" class="data row2 col2" >John</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626row3_col0" class="data row3 col0" >Lady GaGa</td>
#                         <td id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626row3_col1" class="data row3 col1" >Just Dance</td>
#                         <td id="T_dd6e46cc_ae9f_11ea_8fa9_4865ee12e626row3_col2" class="data row3 col2" >John</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626" ><caption>samantha</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626row0_col0" class="data row0 col0" >Black Eyed Peas</td>
#                         <td id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626row0_col1" class="data row0 col1" >Let's Get it Started</td>
#                         <td id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626row0_col2" class="data row0 col2" >Samantha</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626row1_col0" class="data row1 col0" >Panic at the Disco</td>
#                         <td id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626row1_col1" class="data row1 col1" >Hallelujah</td>
#                         <td id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626row1_col2" class="data row1 col2" >Samantha</td>
#             </tr>
#             <tr>
#                         <th id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626row2_col0" class="data row2 col0" >Adele</td>
#                         <td id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626row2_col1" class="data row2 col1" >Set Fire to the Rain</td>
#                         <td id="T_dd6e9728_ae9f_11ea_a1b7_4865ee12e626row2_col2" class="data row2 col2" >Samantha</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# > For now, lets assume we take everyone's recommendations and add them all to our play list, even if the same song has been recommended by someone else.

# %%
df = pd.concat(playlists).reset_index(drop=True)
df
# Out:
#                    artist                            track Recommended By
# 0               Green Day                Time of your Life            Joe
# 1                   B-52s                     Rock Lobster            Joe
# 2               Lady GaGa                       Poker Face            Joe
# 3             John Lennon                          Imagine            Joe
# 4                   Eve 6              Here's to the Night          James
# 5      Neutral Milk Hotel  Into the Aeroplane Over the Sea          James
# 6              Rilo Kiley           With Arms Outstretched          James
# 7   Red Hot Chili Peppers                        Otherside          James
# 8       Smashing Pumpkins                 Tonight, Tonight           Anne
# 9         Black Eyed Peas             Let's Get it Started           Anne
# 10              Green Day                Time of your Life           Anne
# 11        Black Eyed Peas             Let's Get it Started           John
# 12              Lady GaGa                       Poker Face           John
# 13              Lady GaGa                      Bad Romance           John
# 14              Lady GaGa                       Just Dance           John
# 15        Black Eyed Peas             Let's Get it Started       Samantha
# 16     Panic at the Disco                       Hallelujah       Samantha
# 17                  Adele             Set Fire to the Rain       Samantha

# %%
## Making Sample Spaces for Tracks and artists
sTracks = set(df['track'])
sArtists = set(df['artist'])

print(f"There are {len(sTracks)} unique tracks and {len(sArtists)} unique artists.")
# Out:
# There are 14 unique tracks and 12 unique artists.

# %% [markdown]
# #### Q1: What is the probability of the next song being by Lady GaGa?

# %% [markdown]
# (**If we just accept everyone's suggestions (full df) and play on shuffle**)

# %% [markdown]
# $$ P(E) = \frac{|E|}{|S|} $$

# %%
num = df['artist'].value_counts()['Lady GaGa']
denom =  len(df)
num/denom
# Out:
# 0.2222222222222222

# %%
df['artist'].value_counts(normalize=True)
# Out:
# Lady GaGa                0.222222
# Black Eyed Peas          0.166667
# Green Day                0.111111
# Neutral Milk Hotel       0.055556
# John Lennon              0.055556
# Adele                    0.055556
# Red Hot Chili Peppers    0.055556
# B-52s                    0.055556
# Smashing Pumpkins        0.055556
# Panic at the Disco       0.055556
# Eve 6                    0.055556
# Rilo Kiley               0.055556
# Name: artist, dtype: float64

# %%
## get counts for how many times artists appear
counts = df['artist'].value_counts()
counts
# Out:
# Lady GaGa                4
# Black Eyed Peas          3
# Green Day                2
# Neutral Milk Hotel       1
# John Lennon              1
# Adele                    1
# Red Hot Chili Peppers    1
# B-52s                    1
# Smashing Pumpkins        1
# Panic at the Disco       1
# Eve 6                    1
# Rilo Kiley               1
# Name: artist, dtype: int64

# %%
## What is the event space?
event_space = counts.loc['Lady GaGa']# / len(counts)

## What about the sample_space?
sample_space = sum(counts)

# %%
P_lady_gaga = event_space/sample_space
P_lady_gaga
# Out:
# 0.2222222222222222

# %% [markdown]
# #### Q2: What is the probability of the next song being "Time of Your Life"?

# %%
counts = df['track'].value_counts()
counts
# Out:
# Let's Get it Started               3
# Time of your Life                  2
# Poker Face                         2
# Set Fire to the Rain               1
# Hallelujah                         1
# Rock Lobster                       1
# Here's to the Night                1
# Tonight, Tonight                   1
# With Arms Outstretched             1
# Just Dance                         1
# Imagine                            1
# Into the Aeroplane Over the Sea    1
# Bad Romance                        1
# Otherside                          1
# Name: track, dtype: int64

# %%
## What is the cardinality of the event space?
event_space = counts.loc['Time of your Life']# / len(counts)

## What about the sample_space?
sample_space = sum(counts)

# %%
P_time_of_your_life = event_space/sample_space
P_time_of_your_life
# Out:
# 0.1111111111111111

# %% [markdown]
# ## Activity Pt 2: Playlist Permutations

# %% [markdown]
# #### Q1: How many different ways could we build a playlist using everyone's recommendations (without shuffle, no looping, and no repeated songs)?

# %% [markdown]
# - Q: Combination or permutation?
#     -  Permutation

# %% [markdown]
# - Q: What formula would we use?
#  $$\large P(n) = n!$$

# %%
from math import factorial
factorial(len(sTracks))
# Out:
# 87178291200

# %%
"{:,}".format(factorial(len(sTracks)))
# Out:
# '87,178,291,200'

# %% [markdown]
# #### Q2: What if we limit the playlist to only 10 songs, without replacement? How many possible playlists?

# %% [markdown]
# - Q: Combination or permutation?
#     - Permutation

# %% [markdown]
# - Q: What formula would we use?
# $$ \large P_{k}^{n}= \dfrac{n!}{(n-k)!}$$

# %%
len(sTracks)
# Out:
# 14

# %%
p_10_14 = factorial(len(sTracks)) / factorial(len(sTracks)-10)
"{:,}".format(p_10_14)
# Out:
# '3,632,428,800.0'

# %% [markdown]
# #### Q3: what if we limit the playlist to 10 songs, WITH replacement?

# %% [markdown]
# - Q: Combination or permutation?
#     - Permutation

# %% [markdown]
# - Q: What formula would we use?
# $$ \large {P}_{j}^{n} = n^j $$

# %%
p_10_14R = 14**10
"{:,}".format(p_10_14R)
# Out:
# '289,254,654,976'

# %% [markdown]
# #### Q4: what if we select 10 songs out of the total number of suggestions and allow for repitition?

# %% [markdown]
# - Q: Combination or permutation?
#     - Permutation

# %% [markdown]
# - Q: What formula would we use?
# $$\dfrac{n!}{n_1!n_2!\ldots n_j!}$$

# %%
print(df['track'].value_counts().sum())
df['track'].value_counts()
# Out:
# 18
# Let's Get it Started               3
# Time of your Life                  2
# Poker Face                         2
# Set Fire to the Rain               1
# Hallelujah                         1
# Rock Lobster                       1
# Here's to the Night                1
# Tonight, Tonight                   1
# With Arms Outstretched             1
# Just Dance                         1
# Imagine                            1
# Into the Aeroplane Over the Sea    1
# Bad Romance                        1
# Otherside                          1
# Name: track, dtype: int64

# %%
p18R = factorial(18) / (factorial(3)*factorial(2)*factorial(2))
"{:,}".format(p18R)
# Out:
# '266,765,571,072,000.0'

# %% [markdown]
# ### So....  We realize we need to relax and not worry about the song-order. That's what Shuffle is for, right? 😅

# %% [markdown]
# #### Q5: How many playlists can we produce for an 8-track playlist from the unique suggested songs (10)?

# %% [markdown]
# - Q: Combination or permutation?
#     - Combination

# %% [markdown]
# - Q: What formula would we use?
# $$\large C_{k}^{n} = \displaystyle\binom{n}{k} = \dfrac{P_{k}^{n}}{k!}=\dfrac{ \dfrac{n!}{(n-k)!}}{k!} = \dfrac{n!}{(n-k)!k!}$$

# %%
c_8_10 = factorial(10)/ (factorial((10-8))*factorial(8))
"{:,}".format(c_8_10)
# Out:
# '45.0'

# %% [markdown]
# # Sect 11B: Conditional Probability & Law of Total Probability

# %% [markdown]
# - 06/16/20 Study Group

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# - We will review Independent, Dependent, vs Disjointed Events before diving deeper into conditional probability.
# - We will cover conditional probability and its theorems.
# - We will discuss the Law of Total Probability.
#
#
#
# - **Activity: We will extend our dinner party activity to a house party to explore conditional probability and the Law of Total Probability**
# - **Demo: Teaser for Sect 12 (if theres time)**

# %% [markdown]
# ### QUESTIONS?
# - [Questions Doc](https://docs.google.com/document/d/196yIMNSRSRspBdBmjHq7vMhFF-YdpvkyYEHYV5nm8xg/edit?usp=sharing)

# %% [markdown]
# ##  Independent, Dependent, and Disjoint Events

# %% [markdown]
# ### Indepdent Events

# %% [markdown]
# #### If 2 indepedent events:
#
# **Events $A$ and $B$ are independent when the occurrence of $A$ has no effect on whether $B$ will occur (or not).**
#
# - A and B are independent if:
#     - $P(A \cap B) = P(A)\cdot P(B)$
#
# - Probability of A or B occurring:
#     - $P (A \cup B) = P(A) + P(B) - P(A \cap B)$
#
#  <img src="https://raw.githubusercontent.com/jirvingphd/dsc-conditional-probability-online-ds-ft-100719/master/images/Image_67_independent.png" width=400>
#
#  Thus, in the case of two independent events, by substitution,
#
# $$P (A \cup B) = P(A) + P(B) - P(A)P(B).$$
#
# #### If 3 independent events:
# - A, B, and C are independent if:
#     - $P(A \cap B) = P(A)P(B)$
#     - $P(A \cap C) = P(A)P(C)$
#     - $P(B \cap C) = P(B)P(C)$
#     - $P(A \cap B \cap C) = P(A)P(B)P(C)$
#     - So you need both *pairwise independence* and *three-way independence*

# %% [markdown]
# ### Disjoint Events

# %% [markdown]
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-conditional-probability-online-ds-ft-100719/master/images/Image_68Disjoint.png" width=400>
#
#
# **Events $A$ and $B$ are disjoint if $A$ occurring means that $B$ cannot occur.**
#
# Disjoint events are **mutually exclusive**. $P (A \cap B)$ is **empty**.

# %% [markdown]
# ### Dependent Events

# %% [markdown]
# **Events $A$ and $B$ are dependent when the occurrence of $A$ somehow has an effect on whether $B$ will occur (or not).**
#
#
# In simple terms, the probability of seeing an event $B$ in the second trial depends on the outcome $A$ of the first trial. We say that $P(B)$ is **conditional** on $P(A)$.
#
# A **tree diagram** can be used to explore all possible events.
#
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-conditional-probability-online-ds-ft-100719/master/images/Image_71_TreeDiag.png" width = 500>

# %% [markdown]
# ### Conditional Probability Definition

# %% [markdown]
# **Conditional probability emerges when the outcome a trial may influence the results of the upcoming trials.**
#
# The conditional probability (Probability of $A$ **given** $B$) can be written as:
# $$ P (A \mid B) = \dfrac{P(A \cap B)}{P(B)}$$
#
#
#
# $P(A|B)$, is the probability A **given** that $B$ has just happened.

# %% [markdown]
# ### Derivation of Conditional Probability
# Understanding this formula may be easier if you look at two simple Venn Diagrams and use the multiplication rule. Here's how to derive this formula:
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-conditional-probability-online-ds-ft-100719/master/images/Image_72_Cond4.png" width="300">
#
#
#
# Step 1: Write out the multiplication rule:
# * $P(A \cap B)= P(B)*P(A\mid B)$
#
# Step 2: Divide both sides of the equation by P(B):
# * $\dfrac{P(A \cap B)}{ P(B)} = \dfrac{P(B)*P(A\mid B)}{P(B)}$
#
# Step 3: Cancel P(B) on the right side of the equation:
# * $\dfrac{P(A \cap B)}{P(B)} = P(A \mid B)$
#
# Step 4: This is of course equal to:
# * $ P(A \mid B)=\dfrac{P(A \cap B)}{P(B)} $
#
# And this is our conditional probability formula.

# %% [markdown]
# ## ORIGINAL END OF 06/12 Study Group
# ___

# %% [markdown]
# ## 🚨Laws & Theorems Based on Conditional Probability

# %% [markdown]
# ### Theorem 1: Product Rule
#
# The intersection of events $A$ and $B$ can be given by
#
# \begin{align}
#     P(A \cap B) = P(B) P(A \mid B) = P(A) P(B \mid A)
# \end{align}
#
# Remember that if $A$ and $B$ are independent, then conditioning on $B$ means nothing (and vice-versa) so:
# - $P(A|B) = P(A)$, and
# - $P(A \cap B) = P(A) P(B)$.

# %% [markdown]
# ### Theorem 2: Chain Rule AKA "General Product Rule"
#
# - Allows calculation of any member of the joint distribution of a set of random variables using _only_ conditional probabilities.
#
# - Built on the product rule:
# $$P(A \cap B) = P(A \mid B) P(B)$$
#
# - When applied to 3 variables, becomes:
#
#
# $$P(A\cap B \cap C) = P(A\cap( B \cap C))$$
# $$ = P(A\mid B \cap C) P(B \cap C)$$
# $$ = P(A \mid B \cap C) P(B \mid C) P(C)$$
#
# And you can keep extending this to $n$ variables:
#
# $$P(A_1 \cap A_2 \cap \ldots \cap A_n) = P(A_1 \mid A_2 \cap \ldots\cap A_n) P(A_2 \mid A_3  \cap \ldots \cap \ A_n) P(A_{n-1}|A_n) P(A_n)$$
#
# This idea is known as the **chain rule**.

# %% [markdown]
# ### Theorem 3 - Bayes Theorem

# %% [markdown]
# The **Bayes theorem**, which is the outcome of this section. Below is the formula that we will dig deeper into in upcoming lessons.
#
# $$ P(A|B) = \frac{P(B|A)P(A)}{P(B)} $$
#
# - It uses that $P(A \cap B) = P(B) P(A \mid B) = P(A) P(B \mid A)$.
# - Note that, using Bayes theorem, you **can compute conditional probabilities without explicitly needing to know $P(A \cap B)$!**

# %% [markdown]
# ### Additional note: the complement of an event
#
# You learned about (absolute and relative) complements before, but the complement of an event is also applicable to conditional probabilities.
#
# The basic rule is:
#
# $P(A) + P(A') = 1$
#
# with A' being the complement of A.
#
# Similarly, extending this to conditional probabilities:
#
# $P(A|B) + P(A'|B) = 1$

# %% [markdown]
# ## Activity Pt 3: Dinner Party Playlist - Conditional Probabilities

# %% [markdown]
# - Loading in the Data and Adding the Recommendatins of a last minute invitee (Carla)

# %%
import os,glob
datafolder = "../../Mod 2/sect_11/probability_playlists/" ## student filepath
rec_files = glob.glob(datafolder+"*.csv")

playlists = {}
for file in rec_files:
    key = os.path.basename(file).replace('_recs.csv','')
    playlists[key] = pd.read_csv(file)
playlists.keys()
# Out:
# dict_keys(['joe', 'james', 'anne', 'john', 'samantha'])

# %%
### New Attendee, Carla

# Carla's Recs:
carla_recs = [['artist','track']]
carla_recs.append(['Cartman (South Park)','Poker Face'])
carla_recs.append(['Nicki Minaj','Right By My Side'])
carla_recs.append(['Kelly Clarkson',"Since You've Been Gone"])
carla_recs.append(['Nicki Minaj',"Marilyn Monroe"])
carla_recs.append(['Kelly Clarkson',"Never Again"])
carla_recs.append(['Green Day',"Minority"])



carla_recs = pd.DataFrame(carla_recs[1:],columns=carla_recs[0])
carla_recs['Recommended By'] ='Carla'
playlists['carla'] = carla_recs

# %%
for name,playlist in playlists.items():
    display(playlist.style.set_caption(name))
# Out:
# <style  type="text/css" >
# </style><table id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626" ><caption>joe</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626row0_col0" class="data row0 col0" >Green Day</td>
#                         <td id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626row0_col1" class="data row0 col1" >Time of your Life</td>
#                         <td id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626row0_col2" class="data row0 col2" >Joe</td>
#             </tr>
#             <tr>
#                         <th id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626row1_col0" class="data row1 col0" >B-52s</td>
#                         <td id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626row1_col1" class="data row1 col1" >Rock Lobster</td>
#                         <td id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626row1_col2" class="data row1 col2" >Joe</td>
#             </tr>
#             <tr>
#                         <th id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626row2_col0" class="data row2 col0" >Lady GaGa</td>
#                         <td id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626row2_col1" class="data row2 col1" >Poker Face</td>
#                         <td id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626row2_col2" class="data row2 col2" >Joe</td>
#             </tr>
#             <tr>
#                         <th id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626row3_col0" class="data row3 col0" >John Lennon</td>
#                         <td id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626row3_col1" class="data row3 col1" >Imagine</td>
#                         <td id="T_dd84cb06_ae9f_11ea_877c_4865ee12e626row3_col2" class="data row3 col2" >Joe</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_dd852e66_ae9f_11ea_9505_4865ee12e626" ><caption>james</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd852e66_ae9f_11ea_9505_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd852e66_ae9f_11ea_9505_4865ee12e626row0_col0" class="data row0 col0" >Eve 6</td>
#                         <td id="T_dd852e66_ae9f_11ea_9505_4865ee12e626row0_col1" class="data row0 col1" >Here's to the Night</td>
#                         <td id="T_dd852e66_ae9f_11ea_9505_4865ee12e626row0_col2" class="data row0 col2" >James</td>
#             </tr>
#             <tr>
#                         <th id="T_dd852e66_ae9f_11ea_9505_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd852e66_ae9f_11ea_9505_4865ee12e626row1_col0" class="data row1 col0" >Neutral Milk Hotel</td>
#                         <td id="T_dd852e66_ae9f_11ea_9505_4865ee12e626row1_col1" class="data row1 col1" >Into the Aeroplane Over the Sea</td>
#                         <td id="T_dd852e66_ae9f_11ea_9505_4865ee12e626row1_col2" class="data row1 col2" >James</td>
#             </tr>
#             <tr>
#                         <th id="T_dd852e66_ae9f_11ea_9505_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd852e66_ae9f_11ea_9505_4865ee12e626row2_col0" class="data row2 col0" >Rilo Kiley</td>
#                         <td id="T_dd852e66_ae9f_11ea_9505_4865ee12e626row2_col1" class="data row2 col1" >With Arms Outstretched</td>
#                         <td id="T_dd852e66_ae9f_11ea_9505_4865ee12e626row2_col2" class="data row2 col2" >James</td>
#             </tr>
#             <tr>
#                         <th id="T_dd852e66_ae9f_11ea_9505_4865ee12e626level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dd852e66_ae9f_11ea_9505_4865ee12e626row3_col0" class="data row3 col0" >Red Hot Chili Peppers</td>
#                         <td id="T_dd852e66_ae9f_11ea_9505_4865ee12e626row3_col1" class="data row3 col1" >Otherside</td>
#                         <td id="T_dd852e66_ae9f_11ea_9505_4865ee12e626row3_col2" class="data row3 col2" >James</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626" ><caption>anne</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626row0_col0" class="data row0 col0" >Smashing Pumpkins</td>
#                         <td id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626row0_col1" class="data row0 col1" >Tonight, Tonight</td>
#                         <td id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626row0_col2" class="data row0 col2" >Anne</td>
#             </tr>
#             <tr>
#                         <th id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626row1_col0" class="data row1 col0" >Black Eyed Peas</td>
#                         <td id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626row1_col1" class="data row1 col1" >Let's Get it Started</td>
#                         <td id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626row1_col2" class="data row1 col2" >Anne</td>
#             </tr>
#             <tr>
#                         <th id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626row2_col0" class="data row2 col0" >Green Day</td>
#                         <td id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626row2_col1" class="data row2 col1" >Time of your Life</td>
#                         <td id="T_dd85874c_ae9f_11ea_8a55_4865ee12e626row2_col2" class="data row2 col2" >Anne</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626" ><caption>john</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626row0_col0" class="data row0 col0" >Black Eyed Peas</td>
#                         <td id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626row0_col1" class="data row0 col1" >Let's Get it Started</td>
#                         <td id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626row0_col2" class="data row0 col2" >John</td>
#             </tr>
#             <tr>
#                         <th id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626row1_col0" class="data row1 col0" >Lady GaGa</td>
#                         <td id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626row1_col1" class="data row1 col1" >Poker Face</td>
#                         <td id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626row1_col2" class="data row1 col2" >John</td>
#             </tr>
#             <tr>
#                         <th id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626row2_col0" class="data row2 col0" >Lady GaGa</td>
#                         <td id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626row2_col1" class="data row2 col1" >Bad Romance</td>
#                         <td id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626row2_col2" class="data row2 col2" >John</td>
#             </tr>
#             <tr>
#                         <th id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626row3_col0" class="data row3 col0" >Lady GaGa</td>
#                         <td id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626row3_col1" class="data row3 col1" >Just Dance</td>
#                         <td id="T_dd85d500_ae9f_11ea_99c0_4865ee12e626row3_col2" class="data row3 col2" >John</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626" ><caption>samantha</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626row0_col0" class="data row0 col0" >Black Eyed Peas</td>
#                         <td id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626row0_col1" class="data row0 col1" >Let's Get it Started</td>
#                         <td id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626row0_col2" class="data row0 col2" >Samantha</td>
#             </tr>
#             <tr>
#                         <th id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626row1_col0" class="data row1 col0" >Panic at the Disco</td>
#                         <td id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626row1_col1" class="data row1 col1" >Hallelujah</td>
#                         <td id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626row1_col2" class="data row1 col2" >Samantha</td>
#             </tr>
#             <tr>
#                         <th id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626row2_col0" class="data row2 col0" >Adele</td>
#                         <td id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626row2_col1" class="data row2 col1" >Set Fire to the Rain</td>
#                         <td id="T_dd86287a_ae9f_11ea_bf74_4865ee12e626row2_col2" class="data row2 col2" >Samantha</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_dd867654_ae9f_11ea_9f06_4865ee12e626" ><caption>carla</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd867654_ae9f_11ea_9f06_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row0_col0" class="data row0 col0" >Cartman (South Park)</td>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row0_col1" class="data row0 col1" >Poker Face</td>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row0_col2" class="data row0 col2" >Carla</td>
#             </tr>
#             <tr>
#                         <th id="T_dd867654_ae9f_11ea_9f06_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row1_col0" class="data row1 col0" >Nicki Minaj</td>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row1_col1" class="data row1 col1" >Right By My Side</td>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row1_col2" class="data row1 col2" >Carla</td>
#             </tr>
#             <tr>
#                         <th id="T_dd867654_ae9f_11ea_9f06_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row2_col0" class="data row2 col0" >Kelly Clarkson</td>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row2_col1" class="data row2 col1" >Since You've Been Gone</td>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row2_col2" class="data row2 col2" >Carla</td>
#             </tr>
#             <tr>
#                         <th id="T_dd867654_ae9f_11ea_9f06_4865ee12e626level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row3_col0" class="data row3 col0" >Nicki Minaj</td>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row3_col1" class="data row3 col1" >Marilyn Monroe</td>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row3_col2" class="data row3 col2" >Carla</td>
#             </tr>
#             <tr>
#                         <th id="T_dd867654_ae9f_11ea_9f06_4865ee12e626level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row4_col0" class="data row4 col0" >Kelly Clarkson</td>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row4_col1" class="data row4 col1" >Never Again</td>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row4_col2" class="data row4 col2" >Carla</td>
#             </tr>
#             <tr>
#                         <th id="T_dd867654_ae9f_11ea_9f06_4865ee12e626level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row5_col0" class="data row5 col0" >Green Day</td>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row5_col1" class="data row5 col1" >Minority</td>
#                         <td id="T_dd867654_ae9f_11ea_9f06_4865ee12e626row5_col2" class="data row5 col2" >Carla</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# > For now, lets assume we take everyone's recommendations and add them all to our play list, even if the same song has been recommended by someone else.

# %%
df = pd.concat(playlists).reset_index(drop=True)
df
# Out:
#                    artist                            track Recommended By
# 0               Green Day                Time of your Life            Joe
# 1                   B-52s                     Rock Lobster            Joe
# 2               Lady GaGa                       Poker Face            Joe
# 3             John Lennon                          Imagine            Joe
# 4                   Eve 6              Here's to the Night          James
# 5      Neutral Milk Hotel  Into the Aeroplane Over the Sea          James
# 6              Rilo Kiley           With Arms Outstretched          James
# 7   Red Hot Chili Peppers                        Otherside          James
# 8       Smashing Pumpkins                 Tonight, Tonight           Anne
# 9         Black Eyed Peas             Let's Get it Started           Anne
# 10              Green Day                Time of your Life           Anne
# 11        Black Eyed Peas             Let's Get it Started           John
# 12              Lady GaGa                       Poker Face           John
# 13              Lady GaGa                      Bad Romance           John
# 14              Lady GaGa                       Just Dance           John
# 15        Black Eyed Peas             Let's Get it Started       Samantha
# 16     Panic at the Disco                       Hallelujah       Samantha
# 17                  Adele             Set Fire to the Rain       Samantha
# 18   Cartman (South Park)                       Poker Face          Carla
# 19            Nicki Minaj                 Right By My Side          Carla
# 20         Kelly Clarkson           Since You've Been Gone          Carla
# 21            Nicki Minaj                   Marilyn Monroe          Carla
# 22         Kelly Clarkson                      Never Again          Carla
# 23              Green Day                         Minority          Carla

# %% [markdown]
# ### Basic Probability Revisited

# %% [markdown]
# #### **Q: What is the probability of hearing "Let's Get it started"?**

# %%
counts = df['track'].value_counts()#sum()#sort_values('track')
counts
# Out:
# Poker Face                         3
# Let's Get it Started               3
# Time of your Life                  2
# Right By My Side                   1
# Tonight, Tonight                   1
# Bad Romance                        1
# Into the Aeroplane Over the Sea    1
# Imagine                            1
# Just Dance                         1
# With Arms Outstretched             1
# Here's to the Night                1
# Set Fire to the Rain               1
# Rock Lobster                       1
# Marilyn Monroe                     1
# Never Again                        1
# Since You've Been Gone             1
# Minority                           1
# Hallelujah                         1
# Otherside                          1
# Name: track, dtype: int64

# %% [markdown]
# $$P(E) = |E| / |S|  $$

# %%
## Get Event Space
P_lets_get_it = counts.loc["Let's Get it Started"] / len(df)
P_lets_get_it
# Out:
# 0.125

# %% [markdown]
# #### **Q: What is the probability of playing a song by Lady GaGa?**

# %%
counts = df['artist'].value_counts()
display(counts)

P_lady_gaga = counts.loc['Lady GaGa'] / len(df)#df['artist'].unique()
P_lady_gaga
# Out:
# Lady GaGa                4
# Black Eyed Peas          3
# Green Day                3
# Kelly Clarkson           2
# Nicki Minaj              2
# Adele                    1
# John Lennon              1
# Red Hot Chili Peppers    1
# Panic at the Disco       1
# Cartman (South Park)     1
# B-52s                    1
# Rilo Kiley               1
# Neutral Milk Hotel       1
# Smashing Pumpkins        1
# Eve 6                    1
# Name: artist, dtype: int64
# 0.16666666666666666

# %%
df['artist'].value_counts(normalize=True)
# Out:
# Lady GaGa                0.166667
# Black Eyed Peas          0.125000
# Green Day                0.125000
# Kelly Clarkson           0.083333
# Nicki Minaj              0.083333
# Adele                    0.041667
# John Lennon              0.041667
# Red Hot Chili Peppers    0.041667
# Panic at the Disco       0.041667
# Cartman (South Park)     0.041667
# B-52s                    0.041667
# Rilo Kiley               0.041667
# Neutral Milk Hotel       0.041667
# Smashing Pumpkins        0.041667
# Eve 6                    0.041667
# Name: artist, dtype: float64

# %%
4/18
# Out:
# 0.2222222222222222

# %% [markdown]
# ### Conditional Probabilities

# %% [markdown]
# $$ P (A \mid B) = \dfrac{P(A \cap B)}{P(B)}$$

# %% [markdown]
# #### Q: what is the probability of hearing a "Poker Face" given that the song is by Lady GaGa?

# %% [markdown]
# - **Q1: What would be the formula to calculate $P(\text{PokerFace}|\text{LadyGaga})$  ?**

# %% [markdown]
# A:
#
# $$ \large P(\text{PokerFace}|\text{LadyGaga}) =\frac{P(\text{Track:"Poker Face" & Artist:"Lady Gaga"})}{ P(\text{Lady GaGa})} $$

# %%
## Get Value Counts for all tracks
track_counts = df.groupby('artist').get_group('Lady GaGa')['track'].value_counts()
track_counts
# Out:
# Poker Face     2
# Bad Romance    1
# Just Dance     1
# Name: track, dtype: int64

# %% [markdown]
# > <div style="color:red;">INSTRUCTOR NOTE: if you simply grab the value counnts of the track column, we will accidentally combine Cartman/South Park's cover of Poker Face with Lady GaGa</div>

# %%
# INCORRECT - SEE NOTE ABOVE
df['track'].value_counts()
# Out:
# Poker Face                         3
# Let's Get it Started               3
# Time of your Life                  2
# Right By My Side                   1
# Tonight, Tonight                   1
# Bad Romance                        1
# Into the Aeroplane Over the Sea    1
# Imagine                            1
# Just Dance                         1
# With Arms Outstretched             1
# Here's to the Night                1
# Set Fire to the Rain               1
# Rock Lobster                       1
# Marilyn Monroe                     1
# Never Again                        1
# Since You've Been Gone             1
# Minority                           1
# Hallelujah                         1
# Otherside                          1
# Name: track, dtype: int64

# %%
artist_counts = df['artist'].value_counts()
artist_counts
# Out:
# Lady GaGa                4
# Black Eyed Peas          3
# Green Day                3
# Kelly Clarkson           2
# Nicki Minaj              2
# Adele                    1
# John Lennon              1
# Red Hot Chili Peppers    1
# Panic at the Disco       1
# Cartman (South Park)     1
# B-52s                    1
# Rilo Kiley               1
# Neutral Milk Hotel       1
# Smashing Pumpkins        1
# Eve 6                    1
# Name: artist, dtype: int64

# %%
## Calculate manually
P_poker_face_lady_gaga = track_counts.loc['Poker Face'] / artist_counts.loc['Lady GaGa']
P_poker_face_lady_gaga
# Out:
# 0.5

# %%
## Show how groupby and value_counts gives same answer
df.groupby('artist').get_group('Lady GaGa')['track'].value_counts(normalize=True)
# Out:
# Poker Face     0.50
# Bad Romance    0.25
# Just Dance     0.25
# Name: track, dtype: float64

# %% [markdown]
# # Sect 11B Cont'd: LAW OF TOTAL PROBABILITY

# %% [markdown]
# > <div style="color:red">Instructor Note: Jeff you may want to check/modify this info below to match your preferences</div>

# %% [markdown]
# - This law allows us to calculate $P(B)$ from partial/conditional probabilitie of subsets ($A_n$).
# - Requires that the different $A$'s that make up sample space $S$ be disjointed events.
#
# S $A_1, A_2, \dots, A_n$ partition sample space $S$ into disjoint regions that sum up to $S$. In the example, the four regions
#
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-law-of-total-probability-online-ds-ft-100719/master/images/Image_55_TotProb.png">
#
# The probability of a random event $B$ (orange area) can be written down as:
#
# \begin{align}
#     P(B) &= P(B \cap A_1) + P(B \cap A_2) + P(B \cap A_3)+ P(B \cap A_4) \\
#          &= P(B \mid A_1)P(A_1) + P(B \mid A_2)P(A_2) +P(B \mid A_3)P(A_3)+ P(B \mid A_4)P(A_4)
# \end{align}
#
# - using the first theorem above let us find the combined probabilities.
#
#
# #### Law of Total Probability
#
# If $B_1$,$B_2$,$B_3$,$\dots$ is a partition of the sample space S, then for any event A we have
#
# $$P(A)= \sum_i P(A \cap B_i)= \sum_i P(A \mid B_i)P(B_i)$$
#
# Using a Venn diagram, we can pictorially see the idea behind the law of total probability. In the figure below, we have
#
# * $A_1 = A \cap B_1$
# * $A_2 = A \cap B_2$
# * $A_3 = A \cap B_3$

# %% [markdown]
# ## Activity: From Dinner Party Playlist to House Party Playlists

# %% [markdown]
# - We've decided to be a little more adventurous and turn our dinner party into a larger house party.
#     - The House party spread across 4 rooms that we assume people will spread their time evenly across the various rooms:
#         - living room
#         - basement
#         - back patio
#         - kitchen
#
# - We have separate play lists playing at each location that were constructed with our dinner party recommendations.

# %% [markdown]
# #### OUR HOUSE PARTY & LAW OF TOTAL PROB
# - Our House Party is sample space S
# - The 4 rooms are A1,A2,A3,A4
# - B represents the probabilty of hearing a specific song or artist as you wander the house.
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-law-of-total-probability-online-ds-ft-100719/master/images/Image_55_TotProb.png" width=50%>
#
# $$P(A)= \sum_i P(A \cap B_i)= \sum_i P(A \mid B_i)P(B_i)$$

# %%
house_party = dict(living_room = df.sample(12,random_state=12).reset_index(drop=True).copy(),
                   basement = df.sample(10,random_state=321).reset_index(drop=True).copy(), 
                   back_patio = df.sample(9,random_state=42).reset_index(drop=True).copy(),
                  kitchen=df.sample(8,random_state=3210).reset_index(drop=True).copy())

for k,v in house_party.items():
    v['Room'] = k 
    display(v.style.set_caption(f"Playlist for {k}"))

house_party.keys()
# Out:
# <style  type="text/css" >
# </style><table id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626" ><caption>Playlist for living_room</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>        <th class="col_heading level0 col3" >Room</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row0_col0" class="data row0 col0" >Cartman (South Park)</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row0_col1" class="data row0 col1" >Poker Face</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row0_col2" class="data row0 col2" >Carla</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row0_col3" class="data row0 col3" >living_room</td>
#             </tr>
#             <tr>
#                         <th id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row1_col0" class="data row1 col0" >Green Day</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row1_col1" class="data row1 col1" >Minority</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row1_col2" class="data row1 col2" >Carla</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row1_col3" class="data row1 col3" >living_room</td>
#             </tr>
#             <tr>
#                         <th id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row2_col0" class="data row2 col0" >Red Hot Chili Peppers</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row2_col1" class="data row2 col1" >Otherside</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row2_col2" class="data row2 col2" >James</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row2_col3" class="data row2 col3" >living_room</td>
#             </tr>
#             <tr>
#                         <th id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row3_col0" class="data row3 col0" >Lady GaGa</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row3_col1" class="data row3 col1" >Just Dance</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row3_col2" class="data row3 col2" >John</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row3_col3" class="data row3 col3" >living_room</td>
#             </tr>
#             <tr>
#                         <th id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row4_col0" class="data row4 col0" >Green Day</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row4_col1" class="data row4 col1" >Time of your Life</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row4_col2" class="data row4 col2" >Anne</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row4_col3" class="data row4 col3" >living_room</td>
#             </tr>
#             <tr>
#                         <th id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row5_col0" class="data row5 col0" >Lady GaGa</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row5_col1" class="data row5 col1" >Bad Romance</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row5_col2" class="data row5 col2" >John</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row5_col3" class="data row5 col3" >living_room</td>
#             </tr>
#             <tr>
#                         <th id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row6_col0" class="data row6 col0" >Smashing Pumpkins</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row6_col1" class="data row6 col1" >Tonight, Tonight</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row6_col2" class="data row6 col2" >Anne</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row6_col3" class="data row6 col3" >living_room</td>
#             </tr>
#             <tr>
#                         <th id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row7_col0" class="data row7 col0" >Nicki Minaj</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row7_col1" class="data row7 col1" >Marilyn Monroe</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row7_col2" class="data row7 col2" >Carla</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row7_col3" class="data row7 col3" >living_room</td>
#             </tr>
#             <tr>
#                         <th id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row8_col0" class="data row8 col0" >Green Day</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row8_col1" class="data row8 col1" >Time of your Life</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row8_col2" class="data row8 col2" >Joe</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row8_col3" class="data row8 col3" >living_room</td>
#             </tr>
#             <tr>
#                         <th id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row9_col0" class="data row9 col0" >Black Eyed Peas</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row9_col1" class="data row9 col1" >Let's Get it Started</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row9_col2" class="data row9 col2" >Samantha</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row9_col3" class="data row9 col3" >living_room</td>
#             </tr>
#             <tr>
#                         <th id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row10_col0" class="data row10 col0" >Kelly Clarkson</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row10_col1" class="data row10 col1" >Since You've Been Gone</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row10_col2" class="data row10 col2" >Carla</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row10_col3" class="data row10 col3" >living_room</td>
#             </tr>
#             <tr>
#                         <th id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row11_col0" class="data row11 col0" >Black Eyed Peas</td>
#                         <td id="T_dd950a02_ae9f_11ea_9df3_4865ee12e626row11_col1" class="data row11 col1" >Let's Get it Started</td>
#                         <td id="T_dd950a02_ae9f_11ea
# <style  type="text/css" >
# </style><table id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626" ><caption>Playlist for basement</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>        <th class="col_heading level0 col3" >Room</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row0_col0" class="data row0 col0" >Lady GaGa</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row0_col1" class="data row0 col1" >Bad Romance</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row0_col2" class="data row0 col2" >John</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row0_col3" class="data row0 col3" >basement</td>
#             </tr>
#             <tr>
#                         <th id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row1_col0" class="data row1 col0" >Green Day</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row1_col1" class="data row1 col1" >Time of your Life</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row1_col2" class="data row1 col2" >Joe</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row1_col3" class="data row1 col3" >basement</td>
#             </tr>
#             <tr>
#                         <th id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row2_col0" class="data row2 col0" >Kelly Clarkson</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row2_col1" class="data row2 col1" >Never Again</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row2_col2" class="data row2 col2" >Carla</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row2_col3" class="data row2 col3" >basement</td>
#             </tr>
#             <tr>
#                         <th id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row3_col0" class="data row3 col0" >Panic at the Disco</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row3_col1" class="data row3 col1" >Hallelujah</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row3_col2" class="data row3 col2" >Samantha</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row3_col3" class="data row3 col3" >basement</td>
#             </tr>
#             <tr>
#                         <th id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row4_col0" class="data row4 col0" >John Lennon</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row4_col1" class="data row4 col1" >Imagine</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row4_col2" class="data row4 col2" >Joe</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row4_col3" class="data row4 col3" >basement</td>
#             </tr>
#             <tr>
#                         <th id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row5_col0" class="data row5 col0" >Lady GaGa</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row5_col1" class="data row5 col1" >Poker Face</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row5_col2" class="data row5 col2" >John</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row5_col3" class="data row5 col3" >basement</td>
#             </tr>
#             <tr>
#                         <th id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row6_col0" class="data row6 col0" >Lady GaGa</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row6_col1" class="data row6 col1" >Poker Face</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row6_col2" class="data row6 col2" >Joe</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row6_col3" class="data row6 col3" >basement</td>
#             </tr>
#             <tr>
#                         <th id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row7_col0" class="data row7 col0" >Green Day</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row7_col1" class="data row7 col1" >Minority</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row7_col2" class="data row7 col2" >Carla</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row7_col3" class="data row7 col3" >basement</td>
#             </tr>
#             <tr>
#                         <th id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row8_col0" class="data row8 col0" >Red Hot Chili Peppers</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row8_col1" class="data row8 col1" >Otherside</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row8_col2" class="data row8 col2" >James</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row8_col3" class="data row8 col3" >basement</td>
#             </tr>
#             <tr>
#                         <th id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row9_col0" class="data row9 col0" >Cartman (South Park)</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row9_col1" class="data row9 col1" >Poker Face</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row9_col2" class="data row9 col2" >Carla</td>
#                         <td id="T_dd95be8c_ae9f_11ea_8027_4865ee12e626row9_col3" class="data row9 col3" >basement</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_dd965c36_ae9f_11ea_a948_4865ee12e626" ><caption>Playlist for back_patio</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>        <th class="col_heading level0 col3" >Room</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd965c36_ae9f_11ea_a948_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row0_col0" class="data row0 col0" >Smashing Pumpkins</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row0_col1" class="data row0 col1" >Tonight, Tonight</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row0_col2" class="data row0 col2" >Anne</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row0_col3" class="data row0 col3" >back_patio</td>
#             </tr>
#             <tr>
#                         <th id="T_dd965c36_ae9f_11ea_a948_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row1_col0" class="data row1 col0" >Panic at the Disco</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row1_col1" class="data row1 col1" >Hallelujah</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row1_col2" class="data row1 col2" >Samantha</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row1_col3" class="data row1 col3" >back_patio</td>
#             </tr>
#             <tr>
#                         <th id="T_dd965c36_ae9f_11ea_a948_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row2_col0" class="data row2 col0" >Green Day</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row2_col1" class="data row2 col1" >Time of your Life</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row2_col2" class="data row2 col2" >Joe</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row2_col3" class="data row2 col3" >back_patio</td>
#             </tr>
#             <tr>
#                         <th id="T_dd965c36_ae9f_11ea_a948_4865ee12e626level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row3_col0" class="data row3 col0" >Cartman (South Park)</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row3_col1" class="data row3 col1" >Poker Face</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row3_col2" class="data row3 col2" >Carla</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row3_col3" class="data row3 col3" >back_patio</td>
#             </tr>
#             <tr>
#                         <th id="T_dd965c36_ae9f_11ea_a948_4865ee12e626level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row4_col0" class="data row4 col0" >Black Eyed Peas</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row4_col1" class="data row4 col1" >Let's Get it Started</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row4_col2" class="data row4 col2" >John</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row4_col3" class="data row4 col3" >back_patio</td>
#             </tr>
#             <tr>
#                         <th id="T_dd965c36_ae9f_11ea_a948_4865ee12e626level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row5_col0" class="data row5 col0" >Black Eyed Peas</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row5_col1" class="data row5 col1" >Let's Get it Started</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row5_col2" class="data row5 col2" >Anne</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row5_col3" class="data row5 col3" >back_patio</td>
#             </tr>
#             <tr>
#                         <th id="T_dd965c36_ae9f_11ea_a948_4865ee12e626level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row6_col0" class="data row6 col0" >Lady GaGa</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row6_col1" class="data row6 col1" >Bad Romance</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row6_col2" class="data row6 col2" >John</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row6_col3" class="data row6 col3" >back_patio</td>
#             </tr>
#             <tr>
#                         <th id="T_dd965c36_ae9f_11ea_a948_4865ee12e626level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row7_col0" class="data row7 col0" >B-52s</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row7_col1" class="data row7 col1" >Rock Lobster</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row7_col2" class="data row7 col2" >Joe</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row7_col3" class="data row7 col3" >back_patio</td>
#             </tr>
#             <tr>
#                         <th id="T_dd965c36_ae9f_11ea_a948_4865ee12e626level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row8_col0" class="data row8 col0" >Nicki Minaj</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row8_col1" class="data row8 col1" >Marilyn Monroe</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row8_col2" class="data row8 col2" >Carla</td>
#                         <td id="T_dd965c36_ae9f_11ea_a948_4865ee12e626row8_col3" class="data row8 col3" >back_patio</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626" ><caption>Playlist for kitchen</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>        <th class="col_heading level0 col1" >track</th>        <th class="col_heading level0 col2" >Recommended By</th>        <th class="col_heading level0 col3" >Room</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row0_col0" class="data row0 col0" >Red Hot Chili Peppers</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row0_col1" class="data row0 col1" >Otherside</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row0_col2" class="data row0 col2" >James</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row0_col3" class="data row0 col3" >kitchen</td>
#             </tr>
#             <tr>
#                         <th id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row1_col0" class="data row1 col0" >Cartman (South Park)</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row1_col1" class="data row1 col1" >Poker Face</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row1_col2" class="data row1 col2" >Carla</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row1_col3" class="data row1 col3" >kitchen</td>
#             </tr>
#             <tr>
#                         <th id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row2_col0" class="data row2 col0" >Nicki Minaj</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row2_col1" class="data row2 col1" >Marilyn Monroe</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row2_col2" class="data row2 col2" >Carla</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row2_col3" class="data row2 col3" >kitchen</td>
#             </tr>
#             <tr>
#                         <th id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row3_col0" class="data row3 col0" >Nicki Minaj</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row3_col1" class="data row3 col1" >Right By My Side</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row3_col2" class="data row3 col2" >Carla</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row3_col3" class="data row3 col3" >kitchen</td>
#             </tr>
#             <tr>
#                         <th id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row4_col0" class="data row4 col0" >Lady GaGa</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row4_col1" class="data row4 col1" >Poker Face</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row4_col2" class="data row4 col2" >John</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row4_col3" class="data row4 col3" >kitchen</td>
#             </tr>
#             <tr>
#                         <th id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row5_col0" class="data row5 col0" >Rilo Kiley</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row5_col1" class="data row5 col1" >With Arms Outstretched</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row5_col2" class="data row5 col2" >James</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row5_col3" class="data row5 col3" >kitchen</td>
#             </tr>
#             <tr>
#                         <th id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row6_col0" class="data row6 col0" >Lady GaGa</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row6_col1" class="data row6 col1" >Poker Face</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row6_col2" class="data row6 col2" >Joe</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row6_col3" class="data row6 col3" >kitchen</td>
#             </tr>
#             <tr>
#                         <th id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row7_col0" class="data row7 col0" >Lady GaGa</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row7_col1" class="data row7 col1" >Bad Romance</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row7_col2" class="data row7 col2" >John</td>
#                         <td id="T_dd96ed18_ae9f_11ea_8eff_4865ee12e626row7_col3" class="data row7 col3" >kitchen</td>
#             </tr>
#     </tbody></table>
# dict_keys(['living_room', 'basement', 'back_patio', 'kitchen'])

# %%
house_party['living_room']
# Out:
#                    artist                   track Recommended By         Room
# 0    Cartman (South Park)              Poker Face          Carla  living_room
# 1               Green Day                Minority          Carla  living_room
# 2   Red Hot Chili Peppers               Otherside          James  living_room
# 3               Lady GaGa              Just Dance           John  living_room
# 4               Green Day       Time of your Life           Anne  living_room
# 5               Lady GaGa             Bad Romance           John  living_room
# 6       Smashing Pumpkins        Tonight, Tonight           Anne  living_room
# 7             Nicki Minaj          Marilyn Monroe          Carla  living_room
# 8               Green Day       Time of your Life            Joe  living_room
# 9         Black Eyed Peas    Let's Get it Started       Samantha  living_room
# 10         Kelly Clarkson  Since You've Been Gone          Carla  living_room
# 11        Black Eyed Peas    Let's Get it Started           Anne  living_room

# %% [markdown]
# #### Q1: What is the probability of hearing a Green Day song at the house party at any given moment?

# %% [markdown]
# ####  To Calculate $P(GD)$ for a Room
#
# $$ P(\text{Green Day})=\sum_i P(\text{Green Day} \mid \text{Room}_i)P(\text{Room}_i)$$
#
# - Q: **With our 4 rooms, what would our equation look like?**
#     - What is the probability of being in each room?

# %% [markdown]
# - A:
# $$P(\text{Green Day})= P(GD|Room1)\times \frac{1}{4} + P(GD|Room2)\times \frac{1}{4} + P(GD|Room3)\times \frac{1}{4} + P(GD|Room4)\times \frac{1}{4} $$

# %%
## Make a dictionary of prob of being in each room
house_party_room_odds = {'living_room':0.25, 'basement':0.25,
                         'back_patio':0.25, 'kitchen':0.25}#]
house_party_room_odds
# Out:
# {'living_room': 0.25, 'basement': 0.25, 'back_patio': 0.25, 'kitchen': 0.25}

# %%
liv_room_artists = house_party['living_room']['artist'].value_counts()
liv_room_artists
# Out:
# Green Day                3
# Black Eyed Peas          2
# Lady GaGa                2
# Red Hot Chili Peppers    1
# Smashing Pumpkins        1
# Cartman (South Park)     1
# Kelly Clarkson           1
# Nicki Minaj              1
# Name: artist, dtype: int64

# %%
P_gd_given_liv_room = liv_room_artists.loc['Green Day'] /sum(liv_room_artists)
P_gd_given_liv_room
# Out:
# 0.25

# %%
P_gd_room1 = P_gd_given_liv_room * house_party_room_odds['living_room']
P_gd_room1
# Out:
# 0.0625

# %%
def get_prob_by_room(house_party, room,sample_column,outcome,display_counts=True):
    """Calculates the probability of a certain outcome from a specific room"""
    
    res = house_party[room][sample_column].value_counts()
    
    if display_counts:
        caption =f"{sample_column.title()} Counts for {room.title()} (Total= {sum(res)})"
        display(res.to_frame().style.set_caption(caption))#": {sample_column}={outcome}"))
        
    ## In case the song/artist doesn't exist  
    try:
        prob = res.loc[outcome] / sum(res)
    except KeyError:
        print(f'{outcome} not found.')
        prob=0
        
    return prob

# %%
get_prob_by_room(house_party,'living_room','artist','Green Day')
# Out:
# <style  type="text/css" >
# </style><table id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626" ><caption>Artist Counts for Living_Room (Total= 12)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626level0_row0" class="row_heading level0 row0" >Green Day</th>
#                         <td id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626row0_col0" class="data row0 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626level0_row1" class="row_heading level0 row1" >Black Eyed Peas</th>
#                         <td id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626row1_col0" class="data row1 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626level0_row2" class="row_heading level0 row2" >Lady GaGa</th>
#                         <td id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626row2_col0" class="data row2 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626level0_row3" class="row_heading level0 row3" >Red Hot Chili Peppers</th>
#                         <td id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626row3_col0" class="data row3 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626level0_row4" class="row_heading level0 row4" >Smashing Pumpkins</th>
#                         <td id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626row4_col0" class="data row4 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626level0_row5" class="row_heading level0 row5" >Cartman (South Park)</th>
#                         <td id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626row5_col0" class="data row5 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626level0_row6" class="row_heading level0 row6" >Kelly Clarkson</th>
#                         <td id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626row6_col0" class="data row6 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626level0_row7" class="row_heading level0 row7" >Nicki Minaj</th>
#                         <td id="T_dd9e47f4_ae9f_11ea_a70b_4865ee12e626row7_col0" class="data row7 col0" >1</td>
#             </tr>
#     </tbody></table>
# 0.25

# %%
house_party.keys()
# Out:
# dict_keys(['living_room', 'basement', 'back_patio', 'kitchen'])

# %%
## NOW CREATE A FOR LOOP TO CALCULATE THE TOTAL PROB OF HEARING GREEN DAY
total_prob_green_day = 0
sample_column='artist'
event='Green Day'

## For each room in the house party
for room in house_party:
    
    ## Get prob of event from room's space
    prob_event = get_prob_by_room(house_party,room,sample_column,event,
                                  display_counts=True)
    
    ## Get prob of being in taht specific room
    prob_room = house_party_room_odds[room]
       
    ## Calculate P_GD x P_Room
    prob_green_day_room = prob_event * prob_room #* house_party_room_odds[room]
    
    ## 
    total_prob_green_day = total_prob_green_day + prob_green_day_room
    
    print(f"Prob {room} = {round(prob_event,2)} * {prob_room} = {round(prob_green_day_room,3)}")

print(f"\n\n[i] The total probability of hearing Green Day at the party is {round(total_prob_green_day,3)}")
# Out:
# <style  type="text/css" >
# </style><table id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626" ><caption>Artist Counts for Living_Room (Total= 12)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626level0_row0" class="row_heading level0 row0" >Green Day</th>
#                         <td id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626row0_col0" class="data row0 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626level0_row1" class="row_heading level0 row1" >Black Eyed Peas</th>
#                         <td id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626row1_col0" class="data row1 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626level0_row2" class="row_heading level0 row2" >Lady GaGa</th>
#                         <td id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626row2_col0" class="data row2 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626level0_row3" class="row_heading level0 row3" >Red Hot Chili Peppers</th>
#                         <td id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626row3_col0" class="data row3 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626level0_row4" class="row_heading level0 row4" >Smashing Pumpkins</th>
#                         <td id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626row4_col0" class="data row4 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626level0_row5" class="row_heading level0 row5" >Cartman (South Park)</th>
#                         <td id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626row5_col0" class="data row5 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626level0_row6" class="row_heading level0 row6" >Kelly Clarkson</th>
#                         <td id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626row6_col0" class="data row6 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626level0_row7" class="row_heading level0 row7" >Nicki Minaj</th>
#                         <td id="T_dda09d5e_ae9f_11ea_9ca1_4865ee12e626row7_col0" class="data row7 col0" >1</td>
#             </tr>
#     </tbody></table>
# Prob living_room = 0.25 * 0.25 = 0.062
# <style  type="text/css" >
# </style><table id="T_dda13570_ae9f_11ea_97b5_4865ee12e626" ><caption>Artist Counts for Basement (Total= 10)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dda13570_ae9f_11ea_97b5_4865ee12e626level0_row0" class="row_heading level0 row0" >Lady GaGa</th>
#                         <td id="T_dda13570_ae9f_11ea_97b5_4865ee12e626row0_col0" class="data row0 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_dda13570_ae9f_11ea_97b5_4865ee12e626level0_row1" class="row_heading level0 row1" >Green Day</th>
#                         <td id="T_dda13570_ae9f_11ea_97b5_4865ee12e626row1_col0" class="data row1 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dda13570_ae9f_11ea_97b5_4865ee12e626level0_row2" class="row_heading level0 row2" >Cartman (South Park)</th>
#                         <td id="T_dda13570_ae9f_11ea_97b5_4865ee12e626row2_col0" class="data row2 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda13570_ae9f_11ea_97b5_4865ee12e626level0_row3" class="row_heading level0 row3" >Red Hot Chili Peppers</th>
#                         <td id="T_dda13570_ae9f_11ea_97b5_4865ee12e626row3_col0" class="data row3 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda13570_ae9f_11ea_97b5_4865ee12e626level0_row4" class="row_heading level0 row4" >John Lennon</th>
#                         <td id="T_dda13570_ae9f_11ea_97b5_4865ee12e626row4_col0" class="data row4 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda13570_ae9f_11ea_97b5_4865ee12e626level0_row5" class="row_heading level0 row5" >Kelly Clarkson</th>
#                         <td id="T_dda13570_ae9f_11ea_97b5_4865ee12e626row5_col0" class="data row5 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda13570_ae9f_11ea_97b5_4865ee12e626level0_row6" class="row_heading level0 row6" >Panic at the Disco</th>
#                         <td id="T_dda13570_ae9f_11ea_97b5_4865ee12e626row6_col0" class="data row6 col0" >1</td>
#             </tr>
#     </tbody></table>
# Prob basement = 0.2 * 0.25 = 0.05
# <style  type="text/css" >
# </style><table id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626" ><caption>Artist Counts for Back_Patio (Total= 9)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626level0_row0" class="row_heading level0 row0" >Black Eyed Peas</th>
#                         <td id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626row0_col0" class="data row0 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626level0_row1" class="row_heading level0 row1" >Green Day</th>
#                         <td id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626row1_col0" class="data row1 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626level0_row2" class="row_heading level0 row2" >B-52s</th>
#                         <td id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626row2_col0" class="data row2 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626level0_row3" class="row_heading level0 row3" >Lady GaGa</th>
#                         <td id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626row3_col0" class="data row3 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626level0_row4" class="row_heading level0 row4" >Smashing Pumpkins</th>
#                         <td id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626row4_col0" class="data row4 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626level0_row5" class="row_heading level0 row5" >Cartman (South Park)</th>
#                         <td id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626row5_col0" class="data row5 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626level0_row6" class="row_heading level0 row6" >Panic at the Disco</th>
#                         <td id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626row6_col0" class="data row6 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626level0_row7" class="row_heading level0 row7" >Nicki Minaj</th>
#                         <td id="T_dda1de12_ae9f_11ea_b2db_4865ee12e626row7_col0" class="data row7 col0" >1</td>
#             </tr>
#     </tbody></table>
# Prob back_patio = 0.11 * 0.25 = 0.028
# <style  type="text/css" >
# </style><table id="T_dda28b3a_ae9f_11ea_9cdf_4865ee12e626" ><caption>Artist Counts for Kitchen (Total= 8)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dda28b3a_ae9f_11ea_9cdf_4865ee12e626level0_row0" class="row_heading level0 row0" >Lady GaGa</th>
#                         <td id="T_dda28b3a_ae9f_11ea_9cdf_4865ee12e626row0_col0" class="data row0 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_dda28b3a_ae9f_11ea_9cdf_4865ee12e626level0_row1" class="row_heading level0 row1" >Nicki Minaj</th>
#                         <td id="T_dda28b3a_ae9f_11ea_9cdf_4865ee12e626row1_col0" class="data row1 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dda28b3a_ae9f_11ea_9cdf_4865ee12e626level0_row2" class="row_heading level0 row2" >Rilo Kiley</th>
#                         <td id="T_dda28b3a_ae9f_11ea_9cdf_4865ee12e626row2_col0" class="data row2 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda28b3a_ae9f_11ea_9cdf_4865ee12e626level0_row3" class="row_heading level0 row3" >Cartman (South Park)</th>
#                         <td id="T_dda28b3a_ae9f_11ea_9cdf_4865ee12e626row3_col0" class="data row3 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda28b3a_ae9f_11ea_9cdf_4865ee12e626level0_row4" class="row_heading level0 row4" >Red Hot Chili Peppers</th>
#                         <td id="T_dda28b3a_ae9f_11ea_9cdf_4865ee12e626row4_col0" class="data row4 col0" >1</td>
#             </tr>
#     </tbody></table>
# Green Day not found.
# Prob kitchen = 0 * 0.25 = 0.0
#
#
# [i] The total probability of hearing Green Day at the party is 0.14

# %% [markdown]
# ### But wait...what if we have unequal probabilties for being in each room?

# %% [markdown]
# - The True prob of people being in each room is determined by what is going on in that room.
#     - The snacks are in the kitchen (prob=0.4)
#     - The drinks/bar is on the back patio (prob=0.3).
#     - The living room and basement have no special amenities. (prob=0.15 each)

# %%
## Update house_party_room_odds
house_party_room_odds['kitchen'] = 0.4
house_party_room_odds['back_patio'] = 0.3
house_party_room_odds['living_room'] =0.15
house_party_room_odds['basement'] =0.15
house_party_room_odds
# Out:
# {'living_room': 0.15, 'basement': 0.15, 'back_patio': 0.3, 'kitchen': 0.4}

# %%
np.sum(list(house_party_room_odds.values()))
# Out:
# 1.0

# %% [markdown]
# #### Q1: What is the probability of hearing a Lady GaGa song at the house party at any given moment with the new room probabilities?

# %%
total_prob_gaga = 0
sample_column='artist'
event='Lady GaGa'

## For each room in the house party
for room in house_party:
    
    ## Get prob of event from room's space
    prob_event = get_prob_by_room(house_party,room,sample_column,event,
                                  display_counts=True)
    
    ## Get prob of being in taht specific room
    prob_room = house_party_room_odds[room]
       
    ## Calculate P_LG x P_Room
    prob_gaga_room = prob_event * prob_room
    
    ## Add the room's prob to the total prob calculation
    total_prob_gaga = total_prob_gaga + prob_gaga_room
    
    print(f"Prob {room} = {round(prob_event,2)} * {prob_room} = {round(prob_gaga_room,3)}")

total_prob_gaga
# Out:
# <style  type="text/css" >
# </style><table id="T_dda59b38_ae9f_11ea_be43_4865ee12e626" ><caption>Artist Counts for Living_Room (Total= 12)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dda59b38_ae9f_11ea_be43_4865ee12e626level0_row0" class="row_heading level0 row0" >Green Day</th>
#                         <td id="T_dda59b38_ae9f_11ea_be43_4865ee12e626row0_col0" class="data row0 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_dda59b38_ae9f_11ea_be43_4865ee12e626level0_row1" class="row_heading level0 row1" >Black Eyed Peas</th>
#                         <td id="T_dda59b38_ae9f_11ea_be43_4865ee12e626row1_col0" class="data row1 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dda59b38_ae9f_11ea_be43_4865ee12e626level0_row2" class="row_heading level0 row2" >Lady GaGa</th>
#                         <td id="T_dda59b38_ae9f_11ea_be43_4865ee12e626row2_col0" class="data row2 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dda59b38_ae9f_11ea_be43_4865ee12e626level0_row3" class="row_heading level0 row3" >Red Hot Chili Peppers</th>
#                         <td id="T_dda59b38_ae9f_11ea_be43_4865ee12e626row3_col0" class="data row3 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda59b38_ae9f_11ea_be43_4865ee12e626level0_row4" class="row_heading level0 row4" >Smashing Pumpkins</th>
#                         <td id="T_dda59b38_ae9f_11ea_be43_4865ee12e626row4_col0" class="data row4 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda59b38_ae9f_11ea_be43_4865ee12e626level0_row5" class="row_heading level0 row5" >Cartman (South Park)</th>
#                         <td id="T_dda59b38_ae9f_11ea_be43_4865ee12e626row5_col0" class="data row5 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda59b38_ae9f_11ea_be43_4865ee12e626level0_row6" class="row_heading level0 row6" >Kelly Clarkson</th>
#                         <td id="T_dda59b38_ae9f_11ea_be43_4865ee12e626row6_col0" class="data row6 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda59b38_ae9f_11ea_be43_4865ee12e626level0_row7" class="row_heading level0 row7" >Nicki Minaj</th>
#                         <td id="T_dda59b38_ae9f_11ea_be43_4865ee12e626row7_col0" class="data row7 col0" >1</td>
#             </tr>
#     </tbody></table>
# Prob living_room = 0.17 * 0.15 = 0.025
# <style  type="text/css" >
# </style><table id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626" ><caption>Artist Counts for Basement (Total= 10)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626level0_row0" class="row_heading level0 row0" >Lady GaGa</th>
#                         <td id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626row0_col0" class="data row0 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626level0_row1" class="row_heading level0 row1" >Green Day</th>
#                         <td id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626row1_col0" class="data row1 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626level0_row2" class="row_heading level0 row2" >Cartman (South Park)</th>
#                         <td id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626row2_col0" class="data row2 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626level0_row3" class="row_heading level0 row3" >Red Hot Chili Peppers</th>
#                         <td id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626row3_col0" class="data row3 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626level0_row4" class="row_heading level0 row4" >John Lennon</th>
#                         <td id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626row4_col0" class="data row4 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626level0_row5" class="row_heading level0 row5" >Kelly Clarkson</th>
#                         <td id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626row5_col0" class="data row5 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626level0_row6" class="row_heading level0 row6" >Panic at the Disco</th>
#                         <td id="T_dda636e2_ae9f_11ea_aed1_4865ee12e626row6_col0" class="data row6 col0" >1</td>
#             </tr>
#     </tbody></table>
# Prob basement = 0.3 * 0.15 = 0.045
# <style  type="text/css" >
# </style><table id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626" ><caption>Artist Counts for Back_Patio (Total= 9)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626level0_row0" class="row_heading level0 row0" >Black Eyed Peas</th>
#                         <td id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626row0_col0" class="data row0 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626level0_row1" class="row_heading level0 row1" >Green Day</th>
#                         <td id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626row1_col0" class="data row1 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626level0_row2" class="row_heading level0 row2" >B-52s</th>
#                         <td id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626row2_col0" class="data row2 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626level0_row3" class="row_heading level0 row3" >Lady GaGa</th>
#                         <td id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626row3_col0" class="data row3 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626level0_row4" class="row_heading level0 row4" >Smashing Pumpkins</th>
#                         <td id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626row4_col0" class="data row4 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626level0_row5" class="row_heading level0 row5" >Cartman (South Park)</th>
#                         <td id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626row5_col0" class="data row5 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626level0_row6" class="row_heading level0 row6" >Panic at the Disco</th>
#                         <td id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626row6_col0" class="data row6 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626level0_row7" class="row_heading level0 row7" >Nicki Minaj</th>
#                         <td id="T_dda6dc50_ae9f_11ea_bd2c_4865ee12e626row7_col0" class="data row7 col0" >1</td>
#             </tr>
#     </tbody></table>
# Prob back_patio = 0.11 * 0.3 = 0.033
# <style  type="text/css" >
# </style><table id="T_dda788da_ae9f_11ea_9e58_4865ee12e626" ><caption>Artist Counts for Kitchen (Total= 8)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >artist</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dda788da_ae9f_11ea_9e58_4865ee12e626level0_row0" class="row_heading level0 row0" >Lady GaGa</th>
#                         <td id="T_dda788da_ae9f_11ea_9e58_4865ee12e626row0_col0" class="data row0 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_dda788da_ae9f_11ea_9e58_4865ee12e626level0_row1" class="row_heading level0 row1" >Nicki Minaj</th>
#                         <td id="T_dda788da_ae9f_11ea_9e58_4865ee12e626row1_col0" class="data row1 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dda788da_ae9f_11ea_9e58_4865ee12e626level0_row2" class="row_heading level0 row2" >Rilo Kiley</th>
#                         <td id="T_dda788da_ae9f_11ea_9e58_4865ee12e626row2_col0" class="data row2 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda788da_ae9f_11ea_9e58_4865ee12e626level0_row3" class="row_heading level0 row3" >Cartman (South Park)</th>
#                         <td id="T_dda788da_ae9f_11ea_9e58_4865ee12e626row3_col0" class="data row3 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dda788da_ae9f_11ea_9e58_4865ee12e626level0_row4" class="row_heading level0 row4" >Red Hot Chili Peppers</th>
#                         <td id="T_dda788da_ae9f_11ea_9e58_4865ee12e626row4_col0" class="data row4 col0" >1</td>
#             </tr>
#     </tbody></table>
# Prob kitchen = 0.38 * 0.4 = 0.15
# 0.25333333333333335

# %% [markdown]
# ___

# %% [markdown]
# #### Q: what is the probability of hearing a song recommend by Anne?

# %%
house_party['back_patio']
# Out:
#                  artist                 track Recommended By        Room
# 0     Smashing Pumpkins      Tonight, Tonight           Anne  back_patio
# 1    Panic at the Disco            Hallelujah       Samantha  back_patio
# 2             Green Day     Time of your Life            Joe  back_patio
# 3  Cartman (South Park)            Poker Face          Carla  back_patio
# 4       Black Eyed Peas  Let's Get it Started           John  back_patio
# 5       Black Eyed Peas  Let's Get it Started           Anne  back_patio
# 6             Lady GaGa           Bad Romance           John  back_patio
# 7                 B-52s          Rock Lobster            Joe  back_patio
# 8           Nicki Minaj        Marilyn Monroe          Carla  back_patio

# %% [markdown]
# $$ P(AnneRec)=\sum_i P(AnneRec \mid Room_i)P(Room_i)$$

# %%
totel_prob_anne = 0
sample_column='Recommended By'
event='Anne'

## For each room in the house party
for room in house_party:
    
    ## Get prob of event from room's space
    prob_event = get_prob_by_room(house_party,room,sample_column,event,
                                  display_counts=True)
    
    ## Get prob of being in taht specific room
    prob_room = house_party_room_odds[room]
       
    ## Calculate P_LG x P_Room
    prob_gaga_room = prob_event * prob_room
    
    ## Add the room's prob to the total prob calculation
    totel_prob_anne = totel_prob_anne + prob_gaga_room
    
    print(f"Prob {room} = {round(prob_event,2)} * {prob_room} = {round(prob_gaga_room,3)}")

total_prob_gaga
# Out:
# <style  type="text/css" >
# </style><table id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626" ><caption>Recommended By Counts for Living_Room (Total= 12)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626level0_row0" class="row_heading level0 row0" >Carla</th>
#                         <td id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626row0_col0" class="data row0 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626level0_row1" class="row_heading level0 row1" >Anne</th>
#                         <td id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626row1_col0" class="data row1 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626level0_row2" class="row_heading level0 row2" >John</th>
#                         <td id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626row2_col0" class="data row2 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626level0_row3" class="row_heading level0 row3" >James</th>
#                         <td id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626row3_col0" class="data row3 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626level0_row4" class="row_heading level0 row4" >Joe</th>
#                         <td id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626row4_col0" class="data row4 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626level0_row5" class="row_heading level0 row5" >Samantha</th>
#                         <td id="T_ddaaa22c_ae9f_11ea_af9a_4865ee12e626row5_col0" class="data row5 col0" >1</td>
#             </tr>
#     </tbody></table>
# Prob living_room = 0.25 * 0.15 = 0.038
# <style  type="text/css" >
# </style><table id="T_ddab48a8_ae9f_11ea_bbb3_4865ee12e626" ><caption>Recommended By Counts for Basement (Total= 10)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ddab48a8_ae9f_11ea_bbb3_4865ee12e626level0_row0" class="row_heading level0 row0" >Joe</th>
#                         <td id="T_ddab48a8_ae9f_11ea_bbb3_4865ee12e626row0_col0" class="data row0 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_ddab48a8_ae9f_11ea_bbb3_4865ee12e626level0_row1" class="row_heading level0 row1" >Carla</th>
#                         <td id="T_ddab48a8_ae9f_11ea_bbb3_4865ee12e626row1_col0" class="data row1 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_ddab48a8_ae9f_11ea_bbb3_4865ee12e626level0_row2" class="row_heading level0 row2" >John</th>
#                         <td id="T_ddab48a8_ae9f_11ea_bbb3_4865ee12e626row2_col0" class="data row2 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_ddab48a8_ae9f_11ea_bbb3_4865ee12e626level0_row3" class="row_heading level0 row3" >Samantha</th>
#                         <td id="T_ddab48a8_ae9f_11ea_bbb3_4865ee12e626row3_col0" class="data row3 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_ddab48a8_ae9f_11ea_bbb3_4865ee12e626level0_row4" class="row_heading level0 row4" >James</th>
#                         <td id="T_ddab48a8_ae9f_11ea_bbb3_4865ee12e626row4_col0" class="data row4 col0" >1</td>
#             </tr>
#     </tbody></table>
# Anne not found.
# Prob basement = 0 * 0.15 = 0.0
# <style  type="text/css" >
# </style><table id="T_ddabe95c_ae9f_11ea_8532_4865ee12e626" ><caption>Recommended By Counts for Back_Patio (Total= 9)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ddabe95c_ae9f_11ea_8532_4865ee12e626level0_row0" class="row_heading level0 row0" >John</th>
#                         <td id="T_ddabe95c_ae9f_11ea_8532_4865ee12e626row0_col0" class="data row0 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_ddabe95c_ae9f_11ea_8532_4865ee12e626level0_row1" class="row_heading level0 row1" >Joe</th>
#                         <td id="T_ddabe95c_ae9f_11ea_8532_4865ee12e626row1_col0" class="data row1 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_ddabe95c_ae9f_11ea_8532_4865ee12e626level0_row2" class="row_heading level0 row2" >Carla</th>
#                         <td id="T_ddabe95c_ae9f_11ea_8532_4865ee12e626row2_col0" class="data row2 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_ddabe95c_ae9f_11ea_8532_4865ee12e626level0_row3" class="row_heading level0 row3" >Anne</th>
#                         <td id="T_ddabe95c_ae9f_11ea_8532_4865ee12e626row3_col0" class="data row3 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_ddabe95c_ae9f_11ea_8532_4865ee12e626level0_row4" class="row_heading level0 row4" >Samantha</th>
#                         <td id="T_ddabe95c_ae9f_11ea_8532_4865ee12e626row4_col0" class="data row4 col0" >1</td>
#             </tr>
#     </tbody></table>
# Prob back_patio = 0.22 * 0.3 = 0.067
# <style  type="text/css" >
# </style><table id="T_ddac7ed0_ae9f_11ea_9c49_4865ee12e626" ><caption>Recommended By Counts for Kitchen (Total= 8)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Recommended By</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ddac7ed0_ae9f_11ea_9c49_4865ee12e626level0_row0" class="row_heading level0 row0" >Carla</th>
#                         <td id="T_ddac7ed0_ae9f_11ea_9c49_4865ee12e626row0_col0" class="data row0 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_ddac7ed0_ae9f_11ea_9c49_4865ee12e626level0_row1" class="row_heading level0 row1" >John</th>
#                         <td id="T_ddac7ed0_ae9f_11ea_9c49_4865ee12e626row1_col0" class="data row1 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_ddac7ed0_ae9f_11ea_9c49_4865ee12e626level0_row2" class="row_heading level0 row2" >James</th>
#                         <td id="T_ddac7ed0_ae9f_11ea_9c49_4865ee12e626row2_col0" class="data row2 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_ddac7ed0_ae9f_11ea_9c49_4865ee12e626level0_row3" class="row_heading level0 row3" >Joe</th>
#                         <td id="T_ddac7ed0_ae9f_11ea_9c49_4865ee12e626row3_col0" class="data row3 col0" >1</td>
#             </tr>
#     </tbody></table>
# Anne not found.
# Prob kitchen = 0 * 0.4 = 0.0
# 0.25333333333333335

# %% [markdown]
# # Intro to Section 12 - Statistical Distributions (if time)

# %% [markdown]
# - Distributions are directly related to probability, which is a critical concept we will explore more with Hypothesis Testing in Module 3.

# %% [markdown]
# ### Probability Mass Function (AKA Probability Distribution Function)

# %% [markdown]
# #### Flipping a coin

# %%
from collections import Counter
np.random.seed(3210)
def coin_toss(n_flips=10,outcomes=None,verbose=True,ret_outcomes=True):
    if outcomes is None:
        outcomes = []
    
    for toss in range(n_flips):
        result = 'H' if np.random.random() >0.5 else 'T'
        outcomes.append(result)
        
        if verbose: print(f"Toss {toss}: \t{result}")
            
#     if ret_outcomes:
    return outcomes
#     else:        
#         counter = Counter(outcomes)
#         return counter

# %%
outcomes = coin_toss(n_flips=4)
outcomes
# Out:
# Toss 0: 	T
# Toss 1: 	T
# Toss 2: 	T
# Toss 3: 	H
# ['T', 'T', 'T', 'H']

# %%
counter= Counter(outcomes)
counter
# Out:
# Counter({'T': 3, 'H': 1})

# %%
def plot_pmf_vs_hist(counter):
    if isinstance(counter,list):
        from collections import Counter
        counter = Counter(counter)

    fig,ax=plt.subplots(ncols=2,figsize=(12,4))
    pmf = [] 

    for k,v in counter.items():
        pmf.append(round(v/len(outcomes),2))


    ax[0].bar(counter.keys(),pmf)
    ax[0].set(title=f'PMF (sum={np.sum(pmf)})',ylabel='Frequency',xlabel='Outcomes')
    
    ax[1].hist(outcomes)#counter.keys(),counter.values())
    ax[1].set(title=f'Histogram (sum={np.sum(list(counter.values()))})',ylabel='Counts',xlabel='Outcomes')
    plt.tight_layout()
    return fig,ax

# %%
plot_pmf_vs_hist(counter)
# Out:
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec175f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec9de80>],
#        dtype=object))

# %%
outcomes = coin_toss(n_flips=12,outcomes=outcomes)
plot_pmf_vs_hist(outcomes)
# Out:
# Toss 0: 	H
# Toss 1: 	T
# Toss 2: 	T
# Toss 3: 	H
# Toss 4: 	T
# Toss 5: 	T
# Toss 6: 	T
# Toss 7: 	H
# Toss 8: 	T
# Toss 9: 	T
# Toss 10: 	T
# Toss 11: 	T
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f09b978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f137cf8>],
#        dtype=object))

# %%
outcomes = coin_toss(n_flips=21,outcomes=outcomes)
plot_pmf_vs_hist(outcomes)
# Out:
# Toss 0: 	T
# Toss 1: 	H
# Toss 2: 	H
# Toss 3: 	T
# Toss 4: 	H
# Toss 5: 	H
# Toss 6: 	T
# Toss 7: 	H
# Toss 8: 	T
# Toss 9: 	T
# Toss 10: 	H
# Toss 11: 	T
# Toss 12: 	H
# Toss 13: 	T
# Toss 14: 	H
# Toss 15: 	T
# Toss 16: 	T
# Toss 17: 	H
# Toss 18: 	T
# Toss 19: 	H
# Toss 20: 	T
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f2ec5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f31a278>],
#        dtype=object))

# %%
outcomes = coin_toss(n_flips=20,outcomes=outcomes)
plot_pmf_vs_hist(outcomes)
# Out:
# Toss 0: 	T
# Toss 1: 	H
# Toss 2: 	H
# Toss 3: 	T
# Toss 4: 	H
# Toss 5: 	T
# Toss 6: 	T
# Toss 7: 	H
# Toss 8: 	H
# Toss 9: 	H
# Toss 10: 	T
# Toss 11: 	T
# Toss 12: 	T
# Toss 13: 	T
# Toss 14: 	H
# Toss 15: 	H
# Toss 16: 	T
# Toss 17: 	T
# Toss 18: 	T
# Toss 19: 	T
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f499a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f4cc3c8>],
#        dtype=object))

# %%
outcomes = coin_toss(n_flips=200,outcomes=outcomes)
plot_pmf_vs_hist(outcomes)
# Out:
# Toss 0: 	T
# Toss 1: 	T
# Toss 2: 	H
# Toss 3: 	H
# Toss 4: 	H
# Toss 5: 	H
# Toss 6: 	H
# Toss 7: 	T
# Toss 8: 	H
# Toss 9: 	T
# Toss 10: 	H
# Toss 11: 	H
# Toss 12: 	H
# Toss 13: 	H
# Toss 14: 	H
# Toss 15: 	T
# Toss 16: 	H
# Toss 17: 	T
# Toss 18: 	H
# Toss 19: 	H
# Toss 20: 	H
# Toss 21: 	H
# Toss 22: 	T
# Toss 23: 	T
# Toss 24: 	T
# Toss 25: 	H
# Toss 26: 	H
# Toss 27: 	H
# Toss 28: 	H
# Toss 29: 	T
# Toss 30: 	H
# Toss 31: 	T
# Toss 32: 	H
# Toss 33: 	H
# Toss 34: 	T
# Toss 35: 	T
# Toss 36: 	T
# Toss 37: 	T
# Toss 38: 	T
# Toss 39: 	H
# Toss 40: 	H
# Toss 41: 	T
# Toss 42: 	T
# Toss 43: 	H
# Toss 44: 	T
# Toss 45: 	H
# Toss 46: 	H
# Toss 47: 	T
# Toss 48: 	T
# Toss 49: 	T
# Toss 50: 	T
# Toss 51: 	H
# Toss 52: 	H
# Toss 53: 	T
# Toss 54: 	T
# Toss 55: 	H
# Toss 56: 	H
# Toss 57: 	H
# Toss 58: 	T
# Toss 59: 	T
# Toss 60: 	T
# Toss 61: 	H
# Toss 62: 	T
# Toss 63: 	T
# Toss 64: 	T
# Toss 65: 	T
# Toss 66: 	T
# Toss 67: 	H
# Toss 68: 	H
# Toss 69: 	T
# Toss 70: 	H
# Toss 71: 	H
# Toss 72: 	H
# Toss 73: 	H
# Toss 74: 	H
# Toss 75: 	H
# Toss 76: 	H
# Toss 77: 	T
# Toss 78: 	T
# Toss 79: 	H
# Toss 80: 	H
# Toss 81: 	H
# Toss 82: 	T
# Toss 83: 	T
# Toss 84: 	H
# Toss 85: 	T
# Toss 86: 	T
# Toss 87: 	T
# Toss 88: 	T
# Toss 89: 	T
# Toss 90: 	T
# Toss 91: 	T
# Toss 92: 	H
# Toss 93: 	H
# Toss 94: 	H
# Toss 95: 	H
# Toss 96: 	H
# Toss 97: 	T
# Toss 98: 	H
# Toss 99: 	T
# Toss 100: 	T
# Toss 101: 	T
# Toss 102: 	H
# Toss 103: 	H
# Toss 104: 	T
# Toss 105: 	H
# Toss 106: 	H
# Toss 107: 	T
# Toss 108: 	T
# Toss 109: 	T
# Toss 110: 	H
# Toss 111: 	T
# Toss 112: 	T
# Toss 113: 	T
# Toss 114: 	T
# Toss 115: 	H
# Toss 116: 	T
# Toss 117: 	T
# Toss 118: 	H
# Toss 119: 	H
# Toss 120: 	T
# Toss 121: 	T
# Toss 122: 	T
# Toss 123: 	T
# Toss 124: 	T
# Toss 125: 	H
# Toss 126: 	T
# Toss 127: 	T
# Toss 128: 	H
# Toss 129: 	T
# Toss 130: 	H
# Toss 131: 	T
# Toss 132: 	H
# Toss 133: 	T
# Toss 134: 	T
# Toss 135: 	T
# Toss 136: 	T
# Toss 137: 	H
# Toss 138: 	H
# Toss 139: 	H
# Toss 140: 	H
# Toss 141: 	H
# Toss 142: 	T
# Toss 143: 	H
# Toss 144: 	H
# Toss 145: 	H
# Toss 146: 	H
# Toss 147: 	H
# Toss 148: 	H
# Toss 149: 	H
# Toss 150: 	H
# Toss 151: 	T
# Toss 152: 	T
# Toss 153: 	H
# Toss 154: 	H
# Toss 155: 	T
# Toss 156: 	T
# Toss 157: 	T
# Toss 158: 	T
# Toss 159: 	T
# Toss 160: 	H
# Toss 161: 	H
# Toss 162: 	H
# Toss 163: 	H
# Toss 164: 	T
# Toss 165: 	H
# Toss 166: 	H
# Toss 167: 	H
# Toss 168: 	H
# Toss 169: 	T
# Toss 170: 	H
# Toss 171: 	T
# Toss 172: 	H
# Toss 173: 	T
# Toss 174: 	H
# Toss 175: 	T
# Toss 176: 	H
# Toss 177: 	H
# Toss 178: 	T
# Toss 179: 	T
# Toss 180: 	T
# Toss 181: 	H
# Toss 182: 	H
# Toss 183: 	H
# Toss 184: 	H
# Toss 185: 	H
# Toss 186: 	T
# Toss 187: 	T
# Toss 188: 	T
# Toss 189: 	T
# Toss 190: 	T
# Toss 191: 	H
# Toss 192: 	H
# Toss 193: 	H
# Toss 194: 	H
# Toss 195: 	H
# Toss 196: 	T
# Toss 197: 	H
# Toss 198: 	T
# Toss 199: 	H
# (<Figure size 864x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f658828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ef141d0>],
#        dtype=object))
